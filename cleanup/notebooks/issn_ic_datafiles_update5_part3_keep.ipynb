# %% [markdown]
# # update5 - TBD

# %%
import sys

# %%
sys.path.append('../..')

# %%
from datetime import datetime, timezone
import json
from tqdm import tqdm
from pathlib import Path
import gzip
import pickle

# %%
import pandas as pd
import numpy as np

# %%
import rapidfuzz

# %%
from app import db
from models import Source, ISSNtoISSNL
from models.source import DELETED_SOURCE_ID
from sqlalchemy import text
from sqlalchemy.orm import Load
from sqlalchemy.exc import MultipleResultsFound
# Out:
# 139824131264896: loading merged_into_institutions_dict
# 139824131264896: loading valid concept IDs
# 139824131264896: loading valid topic IDs
# 139824131264896: loading valid keyword IDs

# %%
from cleanup.util import make_request, paginate_openalex

# %%
# %%time
sq = """select if.*, ife.cluster_title from issn_audit_20240321.issn_ic_datafile_202402 if
left join issn_audit_20240321.issn_ic_datafile_expanded_202402 ife
  on if."submitted_1348-0278"  = ife.issns;"""
df_issnl_file = pd.read_sql_query(sq, db.engine)
# Out:
# CPU times: user 571 ms, sys: 171 ms, total: 743 ms
# Wall time: 1.94 s

# %%
df_issnl_file = df_issnl_file.rename(columns={"submitted_1348-0278": "submitted_issn"})

# %%
# %%time
sq = """select journal_id, display_name, issn, issns, issns_text_array, type, country_code, alternate_titles, publisher_id
    from mid.journal
    where merge_into_id is null"""
df_midjournal = pd.read_sql_query(sq, db.engine)
# Out:
# CPU times: user 1.49 s, sys: 160 ms, total: 1.65 s
# Wall time: 2.97 s

# %%
print(len(df_midjournal))
df_midjournal.dropna(subset='issn', inplace=True)
print(len(df_midjournal))
# Out:
# 256658
# 143411

# %%
smap = {}
for source_id, issn_list in tqdm(df_midjournal.set_index('journal_id', verify_integrity=True)['issns_text_array'].items(), total=len(df_midjournal)):
    for issn in issn_list:
        if issn in smap:
            smap[issn].append(source_id)
        else:
            smap[issn] = [source_id]
# Out:
#   0%|          | 0/143411 [00:00<?, ?it/s]
# 100%|██████████| 143411/143411 [00:00<00:00, 486816.76it/s]

# %%
d = []
for issn, source_list in smap.items():
    d.append({
        'issn': issn,
        'num_sources': len(source_list),
    })
_df = pd.DataFrame(d)
_df['num_sources'].value_counts()
df_issnl_file['num_sources_resolve'] = df_issnl_file['submitted_issn'].map(_df.set_index('issn', verify_integrity=True)['num_sources'])
df_issnl_file['num_sources_resolve'].fillna(value=0, inplace=True)

# %%
# actual_works_count = []
# subset = {issn: source_list for issn, source_list in smap.items() if len(source_list) > 1}
# for issn, source_list in tqdm(subset.items()):
#     if len(source_list) > 1:
#         for source_id in source_list:
#             url = f'https://api.openalex.org/works?filter=locations.source.id:S{source_id}'
#             params = {'mailto': 'jportenoy@ourresearch.org',
#                       'select': 'id',
#                       'per-page': 1}
#             r = make_request(url, params=params)
#             this_c = r.json()['meta']['count']
#             actual_works_count.append({
#                 'issn': issn,
#                 'source_id': source_id,
#                 'works_count': this_c,
#             })
# df_actual_works_count = pd.DataFrame(actual_works_count)

# %%
df_actual_works_count = pd.read_pickle('../data/issn_audit_20240301/df_actual_works_count.pickle')

# %%
x = df_actual_works_count[['source_id', 'works_count']].drop_duplicates()
x = x.set_index('source_id', verify_integrity=True)['works_count']
df_midjournal['works_count'] = df_midjournal['journal_id'].map(x)

# %%
# %%time
url = "https://api.openalex.org/sources"
params = {
    'mailto': 'jportenoy@ourresearch.org',
    'group_by': 'issn',
    'bypass_cache': 'true',
}
data = []
for r in paginate_openalex(url, params=params):
    data.extend(r.json()['group_by'])
# Out:
# CPU times: user 7.87 s, sys: 394 ms, total: 8.26 s
# Wall time: 4min 27s

# %%
df_sources = pd.DataFrame(data)
_rename = {
    'key': 'issn',
    'count': 'num_sources_in_openalex',
}
df_openalex_issn_sources_count = df_sources.rename(columns=_rename).drop(columns=['key_display_name'])

# %%
df_openalex_issn_sources_count['num_sources_in_openalex'].value_counts()
# Out:
# num_sources_in_openalex
# 1    216119
# 2      1395
# 3        12
# Name: count, dtype: int64

# %%
df_issn_to_issnl = pd.read_sql_query("""select * from mid.journal_issn_to_issnl""", db.engine)

# %%
issn_to_issnl = df_issn_to_issnl.set_index('issn', verify_integrity=True)['issnl']

# %%
issnls = issn_to_issnl.unique()

# %%
def get_all_sources_db(issn, session):
    sources1 = session.query(Source).options(Load(Source).lazyload('*')).filter_by(merge_into_id=None).filter_by(issn=issn).all()
    sources2 = session.query(Source).options(Load(Source).lazyload('*')).filter_by(merge_into_id=None).filter(Source.issns.contains(issn)).all()
    return set(sources1 + sources2)

# %%
# try:
#     dups_data = {}
#     num_sources_verify = []
#     works_count_map = df_midjournal.set_index('journal_id', verify_integrity=True)['works_count']
#     for issn, row in tqdm(df_mult.set_index('issn', verify_integrity=True).iterrows(), total=len(df_mult)):
#         this_issn_data = []
#         sources = get_all_sources_db(issn, db.session)
#         num_sources_verify.append({
#             'issn': issn,
#             'num_sources_in_openalex': row['num_sources_in_openalex'],
#             'num_sources_db': len(sources),
#         })
#         for source in sources:
#             fuzzratio = rapidfuzz.fuzz.ratio(source.display_name, row['title'], processor=rapidfuzz.utils.default_process)
#             this_issn_data.append({
#                 'source_id': source.id,
#                 'fuzzratio': fuzzratio,
#                 'works_count': works_count_map[source.id]
#             })
#         dups_data[issn] = this_issn_data
# finally:
#     db.session.close()

# %%
fp = Path('../data/issn_audit_20240301/dups_data.pickle')
dups_data = pickle.loads(fp.read_bytes())

# %%
issnldups = df_midjournal.dropna(subset='issn')
issnldups = issnldups[issnldups['issn'].duplicated(keep=False)]
print(len(issnldups))
issnldups = issnldups[issnldups['issn'].isin(issnls)]
print(len(issnldups))
print(issnldups['issn'].nunique())
print(issnldups['journal_id'].nunique())
# Out:
# 52
# 32
# 15
# 32

# %%
issnldups.sort_values('issn')
# Out:
#         journal_id                                       display_name
# 59673   2764753162                                Crustacean research  \
# 46609   4386621722                                Crustacean Research
# 35994   4393914634  Würzburger Jahrbücher für die Altertumswissens...
# 58128   4306535007  Würzburger Jahrbücher für die Altertumswissens...
# 46678   4386621727  Transactions of the Architectural Institute of...
# 153308  2764951900  Transactions of the Architectural Institute of...
# 36101   4393915153                  Urbanistica informazioni (Online)
# 94499   4306533961                           URBANISTICA INFORMAZIONI
# 36096   4393915164                  La Legislazione penale (Online)
# 50374   4306518029                             LA LEGISLAZIONE PENALE
# 36501   4393915626          Ciencia y tecnología del mar (En línea)
# 122875  4306506282                       Ciencia y Tecnología del Mar
# 101727  4306528123                     Revue Archéologique de l'Ouest
# 157123  4210192068                     Revue archéologique de l'Ouest
# 46577   4386621721                     Revue archéologique de l Ouest
# 37870   4393916367                        Medical history. Supplement
# 14323   4392228800                        Medical History Supplements
# 157085  4306512670    ICIDCA Sobre los Derivados de la Caña de Azúcar
# 37742   4393916609  ICIDCA sobre los derivados de la caña de azúca...
# 87725   4306528604                      Rivista di diritto tributario
# 38738   4393917092             Rivista di diritto tributario (Online)
# 149613  4306528605                      RIVISTA DI DIRITTO TRIBUTARIO
# 38906   4393917365                      Literaturkritik.de (Internet)
# 135728  4306518789                                 Literaturkritik.de
# 156869  4386621731                                     Law and Safety
# 48736   4210222736                                    Право і безпека
# 43216   4393918019                    Protokolle zur Bibel (Internet)
# 156878  4306524739                               Protokolle zur Bibel
# 43313   4393918136  Journal of Preschool and Elementary School Edu...
# 23963   4210178752  Journal of Preschool and Elementary School Edu...
# 156428  4220651409             Proceedings of the IAHR World Congress
# 46123   4385749601  8th IAHR World Congress - "Water: Connecting t...
#
#              issn                                    issns
# 59673   0287-3478                            ["2189-5317"]  \
# 46609   0287-3478               ["0287-3478", "2189-5317"]
# 35994   0342-5932               ["0342-5932", "2365-8444"]
# 58128   0342-5932                            ["2365-8444"]
# 46678   0387-1185               ["0387-1185", "2433-0027"]
# 153308  0387-1185                            ["2433-0035"]
# 36101   0392-5005               ["0392-5005", "2239-4222"]
# 94499   0392-5005                            ["2239-4222"]
# 36096   0393-134X               ["0393-134X", "2421-552X"]
# 50374   0393-134X                            ["2421-552X"]
# 36501   0716-2006               ["0716-2006", "0718-0969"]
# 122875  0716-2006                            ["0718-0969"]
# 101727  0767-709X                            ["1775-3732"]
# 157123  0767-709X                            ["1775-3732"]
# 46577   0767-709X               ["0767-709X", "1775-3732"]
# 37870   0950-5571                            ["0950-5571"]
# 14323   0950-5571                            ["2049-3428"]
# 157085  1025-3076                            ["2410-8529"]
# 37742   1025-3076               ["1025-3076", "2410-8529"]
# 87725   1121-4074                            ["2499-2569"]
# 38738   1121-4074               ["1121-4074", "2499-2569"]
# 149613  1121-4074                            ["2499-2569"]
# 38906   1437-9309               ["1437-9309", "1437-9317"]
# 135728  1437-9309                            ["1437-9317"]
# 156869  1727-1584               ["1727-1584", "2617-2933"]
# 48736   1727-1584                            ["2617-2933"]
# 43216   1996-0042               ["1996-0042", "2412-2467"]
# 156878  1996-0042                            ["2412-2467"]
# 43313   2084-7998  ["2084-7998", "2543-7585", "2543-8409"]
# 23963   2084-7998               ["2543-7585", "2543-8409"]
# 156428  2521-7119                            ["2521-716X"]
# 46123   2521-7119                            ["2521-7119"]
#
#                          issns_text_array        type country_code
# 59673                         [2189-5317]     journal           JP  \
# 46609              [0287-3478, 2189-5317]     journal         None
# 35994              [0342-5932, 2365-8444]     journal         None
# 58128                         [2365-8444]     journal         None
# 46678              [0387-1185, 2433-0027]     journal         None
# 153308                        [2433-0035]     journal           JP
# 36101              [0392-5005, 2239-4222]     journal         None
# 94499                         [2239-4222]     journal         None
# 36096              [0393-134X, 2421-552X]     journal         None
# 50374                         [2421-552X]     journal         None
# 36501              [0716-2006, 0718-0969]     journal         None
# 122875                        [0718-0969]     journal         None
# 101727                        [1775-3732]     journal         None
# 157123                        [1775-3732]     journal           FR
# 46577              [0767-709X, 1775-3732]     journal         None
# 37870                         [0950-5571]     journal         None
# 14323                         [2049-3428]        None         None
# 157085                        [2410-8529]     journal         None
# 37742              [1025-3076, 2410-8529]     journal         None
# 87725                         [2499-2569]     journal         None
# 38738              [1121-4074, 2499-2569]     journal         None
# 149613                        [2499-2569]     journal         None
# 38906              [1437-9309, 1437-9317]     journal         None
# 135728                        [1437-9317]     journal         None
# 156869             [1727-1584, 2617-2933]     journal         None
# 48736                         [2617-2933]     journal           UA
# 43216              [1996-0042, 2412-2467]     journal         None
# 156878                        [2412-2467]     journal         None
# 43313   [2084-7998, 2543-7585, 2543-8409]     journal         None
# 23963              [2543-7585, 2543-8409]     journal           PL
# 156428                        [2521-716X]     journal         None
# 46123                         [2521-7119]  conference         None
#
#                                          alternate_titles  publisher_id
# 59673   [Crustacean research, Researches on crustacea,...           NaN  \
# 46609                                                None           NaN
# 35994                                                None           NaN
# 58128                                                  []           NaN
# 46678                                                None  4.320801e+09
# 153308  [Transactions of the Architectural Institute o...  4.320801e+09
# 36101                                                None           NaN
# 94499                                                  []  4.310318e+09
# 36096                                                None           NaN
# 50374                                                  []           NaN
# 36501                                                None           NaN
# 122875                                                 []           NaN
# 101727                                                 []           NaN
# 157123                                              [RAO]           NaN
# 46577                                                None  4.323284e+09
# 37870                                                None           NaN
# 14323                                                None           NaN
# 157085                                                 []           NaN
# 37742                                                None           NaN
# 87725                                                  []           NaN
# 38738                                                None           NaN
# 149613                                                 []           NaN
# 38906                                                None           NaN
# 135728                                                 []           NaN
# 156869                                               None           NaN
# 48736   [Naukovij žurnal, Pravo i bezopasnostʹ, Law an...           NaN
# 43216                                                None           NaN
# 156878                                                 []           NaN
# 43313                                                None           NaN
# 23963                                                  []           NaN
# 156428  [Proceedings of the International Association ...           NaN
# 46123                                                None           NaN
#
#         works_count
# 59673          27.0
# 46609         426.0
# 35994           0.0
# 58128         487.0
# 46678           NaN
# 153308          NaN
# 36101           0.0
# 94499         254.0
# 36096           0.0
# 50374         138.0
# 36501           0.0
# 122875        144.0
# 101727        198.0
# 157123         46.0
# 46577         596.0
# 37870           NaN
# 14323           NaN
# 157085        101.0
# 37742           0.0
# 87725         477.0
# 38738           0.0
# 149613        102.0
# 38906           2.0
# 135728         95.0
# 156869        467.0
# 48736           2.0
# 43216           0.0
# 156878         89.0
# 43313          17.0
# 23963          40.0
# 156428          NaN
# 46123           NaN

# %%
# try:
#     dups_data2 = {}
#     num_sources_verify = []
#     works_count_map = df_midjournal.set_index('journal_id', verify_integrity=True)['works_count']
#     for issn, row in tqdm(df_mult.set_index('issn', verify_integrity=True).iterrows(), total=len(df_mult)):
#         this_issn_data = []
#         sources = get_all_sources_db(issn, db.session)
#         num_sources_verify.append({
#             'issn': issn,
#             'num_sources_in_openalex': row['num_sources_in_openalex'],
#             'num_sources_db': len(sources),
#         })
#         for source in sources:
#             fuzzratio = rapidfuzz.fuzz.ratio(source.display_name, row['title'], processor=rapidfuzz.utils.default_process)
#             this_issn_data.append({
#                 'source_id': source.id,
#                 'fuzzratio': fuzzratio,
#                 'works_count': works_count_map[source.id]
#             })
#         dups_data2[issn] = this_issn_data
# finally:
#     db.session.close()

# %%
#go through each of these above (groupby issn, which should be the issnl), and dedup. delete any which aren't issnls (maybe check them for data later).
#add missing sources from data file (any issnl that doesn't have a source_id identified by issnl)
#this should leave us with no duplicate issns
#then figure out how to resolve any issns that resolve to multiple

# %% [markdown]
# just merge all of them

# %%
# %%time
try:
    num_updated = 0
    n_issn = issnldups['issn'].nunique()
    not_actually_dups = []
    for issn, gbdf in tqdm(issnldups.set_index('journal_id', verify_integrity=True).groupby('issn'), total=n_issn):
        now = datetime.now(timezone.utc).isoformat()
        if len(gbdf) < 2:
            # come back to these
            not_actually_dups.append(issn)
            continue
        # sort by [works_count:desc, source_id:asc]
        gbdf = gbdf.sort_values(['works_count', 'journal_id'], ascending=[False, True])

        merge_into_id = int(gbdf.iloc[0].name)
        for id_to_merge in gbdf.iloc[1:].index:
            id_to_merge = int(id_to_merge)
            source = db.session.query(Source).filter_by(journal_id=id_to_merge).one()
            source.merge_into_id = merge_into_id
            source.merge_into_date = now
            source.updated_date = now

            db.session.add(source)

            note = f"merged because duplicate issnl."
            row = gbdf.loc[id_to_merge].fillna(value=0)
            if row['publisher_id'] or row['alternate_titles']:
                note += " may have additional info."

            sq = """INSERT INTO issn_audit_20240321.update5
                    (source_id, updated_date, merge_into_id, note)
                    VALUES(:source_id, :now, :merge_into_id, :note);"""
            db.session.execute(text(sq), {
                'source_id': source.id,
                'now': now,
                'merge_into_id': merge_into_id,
                'note': note,
            })

            # sq = """update issn_audit_20240321.issn_ic_datafile_202402 set resolved = true
            #     where "submitted_1348-0278" = :issn"""
            # db.session.execute(text(sq), {
            #     'issn': issn,
            # })

            num_updated += 1
    db.session.commit()
    print(f"{num_updated} updated")
finally:
    db.session.close
# Out:
# 100%|██████████| 15/15 [00:08<00:00,  1.78it/s]
# 17 updated
# CPU times: user 240 ms, sys: 37.7 ms, total: 278 ms
# Wall time: 8.79 s

# %%
not_actually_dups
# Out:
# []

# %%
def manual_merge(id_to_merge, merge_into_id, issn, note="manual merge."):

    now = datetime.now(timezone.utc).isoformat()
    source = db.session.query(Source).filter_by(journal_id=id_to_merge).one()
    source.merge_into_id = merge_into_id
    source.merge_into_date = now
    source.updated_date = now

    db.session.add(source)

    sq = """INSERT INTO issn_audit_20240321.update5
            (source_id, updated_date, merge_into_id, note)
            VALUES(:source_id, :now, :merge_into_id, :note);"""
    db.session.execute(text(sq), {
        'source_id': source.id,
        'now': now,
        'merge_into_id': merge_into_id,
        'note': note,
    })

    sq = """update issn_audit_20240321.issn_ic_datafile_202402 set resolved = true
        where "submitted_1348-0278" = :issn"""
    db.session.execute(text(sq), {
        'issn': issn,
    })

# %%
issnldups[issnldups['issn']=='0387-1185']
# Out:
#         journal_id                                       display_name
# 46595   4386621727  Transactions of the Architectural Institute of...  \
# 153235  2764951900  Transactions of the Architectural Institute of...
#
#              issn                       issns        issns_text_array
# 46595   0387-1185  ["0387-1185", "2433-0027"]  [0387-1185, 2433-0027]  \
# 153235  0387-1185               ["2433-0035"]             [2433-0035]
#
#            type country_code
# 46595   journal         None  \
# 153235  journal           JP
#
#                                          alternate_titles  publisher_id
# 46595                                                None  4.320801e+09  \
# 153235  [Transactions of the Architectural Institute o...  4.320801e+09
#
#         works_count
# 46595           NaN
# 153235          NaN

# %%
issn_to_issnl[issn_to_issnl=='0387-1185']
# Out:
# issn
# 0387-1185    0387-1185
# 2433-0027    0387-1185
# 2433-0035    0387-1185
# Name: issnl, dtype: object

# %%
df_issnl_file[df_issnl_file['submitted_issn']=='2433-0035']
# Out:
#         index submitted_issn       issn      issnl  category  medium
# 17688  141933      2433-0035  2433-0035  0387-1185  Register  Online  \
#
#       frequency country center            language start   end
# 17688    Annual   JAPAN  Japan  Multiple languages  1965  1967  \
#
#                                                    title comment  resolved
# 17688  Nihon Kenchiku Gakkai ronbun hokokushu, gogai,...             False  \
#
#                                            cluster_title  num_sources_resolve
# 17688  Nihon Kenchiku Gakkai ronbun hokokushu/Nihon K...                  1.0

# %%
try:
    manual_merge(4386621727, 2764951900, '0387-1185')
finally:
    db.session.close()
