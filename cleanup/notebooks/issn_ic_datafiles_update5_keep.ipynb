# %% [markdown]
# # update5 - TBD

# %%
import sys

# %%
sys.path.append('../..')

# %%
from datetime import datetime, timezone
import json
from tqdm import tqdm
from pathlib import Path
import gzip

# %%
import pandas as pd
import numpy as np

# %%
import rapidfuzz

# %%
from app import db
from models import Source, ISSNtoISSNL
from sqlalchemy import text
from sqlalchemy.orm import Load
from sqlalchemy.exc import MultipleResultsFound
# Out:
# 140618705400192: loading merged_into_institutions_dict
# 140618705400192: loading valid concept IDs
# 140618705400192: loading valid topic IDs

# %%
from cleanup.util import make_request, paginate_openalex

# %%
# %%time
df_issnl_file = pd.read_sql_query('select * from issn_audit_20240321.issn_ic_datafile_expanded_202402', db.engine)
# Out:
# CPU times: user 1.33 s, sys: 283 ms, total: 1.61 s
# Wall time: 4.87 s

# %%
# %%time
sq = """select journal_id, display_name, issn, issns, issns_text_array, type, country_code, alternate_titles, publisher_id
    from mid.journal
    where merge_into_id is null"""
df_midjournal = pd.read_sql_query(sq, db.engine)
# Out:
# CPU times: user 1.83 s, sys: 76.4 ms, total: 1.91 s
# Wall time: 2.92 s

# %%
print(len(df_midjournal))
df_midjournal.dropna(subset='issn', inplace=True)
print(len(df_midjournal))
# Out:
# 261662
# 148415

# %%
smap = {}
for source_id, issn_list in tqdm(df_midjournal.set_index('journal_id', verify_integrity=True)['issns_text_array'].items(), total=len(df_midjournal)):
    for issn in issn_list:
        if issn in smap:
            smap[issn].append(source_id)
        else:
            smap[issn] = [source_id]
# Out:
#   0%|          | 0/148415 [00:00<?, ?it/s]
# 100%|██████████| 148415/148415 [00:00<00:00, 412052.52it/s]

# %%
d = []
for issn, source_list in smap.items():
    d.append({
        'issn': issn,
        'num_sources': len(source_list),
    })
_df = pd.DataFrame(d)
_df['num_sources'].value_counts()
df_issnl_file['num_sources_resolve'] = df_issnl_file['issns'].map(_df.set_index('issn', verify_integrity=True)['num_sources'])
df_issnl_file['num_sources_resolve'].fillna(value=0, inplace=True)

# %%
actual_works_count = []
subset = {issn: source_list for issn, source_list in smap.items() if len(source_list) > 1}
for issn, source_list in tqdm(subset.items()):
    if len(source_list) > 1:
        for source_id in source_list:
            url = f'https://api.openalex.org/works?filter=locations.source.id:S{source_id}'
            params = {'mailto': 'jportenoy@ourresearch.org',
                      'select': 'id',
                      'per-page': 1}
            r = make_request(url, params=params)
            this_c = r.json()['meta']['count']
            actual_works_count.append({
                'issn': issn,
                'source_id': source_id,
                'works_count': this_c,
            })
df_actual_works_count = pd.DataFrame(actual_works_count)
# Out:
#   0%|          | 0/8478 [00:00<?, ?it/s]
# 100%|██████████| 8478/8478 [53:05<00:00,  2.66it/s]

# %%
df_actual_works_count.to_pickle('../data/issn_audit_20240301/df_actual_works_count.pickle')

# %%
df_actual_works_count[['source_id', 'works_count']].drop_duplicates(subset='source_id')
# Out:
#         source_id  works_count
# 0      4306509401        28717
# 1      4210198465            0
# 6      4210204044            0
# 7      4210226537           55
# 8      4210219813            1
# ...           ...          ...
# 17166  2765054898           24
# 17167  4210203785          478
# 17168  4210186117            0
# 17169  4386621981            7
# 17170  2764510533          250
#
# [11226 rows x 2 columns]

# %%
x = df_actual_works_count[['source_id', 'works_count']].drop_duplicates()
x = x.set_index('source_id', verify_integrity=True)['works_count']
df_midjournal['works_count'] = df_midjournal['journal_id'].map(x)

# %%
df_midjournal.dropna(subset='works_count').sort_values('issn')
# Out:
#         journal_id                                       display_name
# 77457   4306504666                  Boletín de la Academia Colombiana  \
# 55224   4306504665                  Boletín de la Academia colombiana
# 52174   4306500404                             Acta medica Philippina
# 40108   4210231482                             Acta Medica Philippina
# 58242   4306500432          Acta Obstetrica et Gynaecologica Japonica
# ...            ...                                                ...
# 35607   4392785010  Journal of Physical Mathematics & its Applicat...
# 7618    4393248715                       Millatuna Jurnal Studi Islam
# 55418   4393923809                      THRIVE Health Science Journal
# 35562   4210203606                 The Year book of pulmonary disease
# 119802    50342286                      Yearbook of Pulmonary Disease
#
#              issn                       issns        issns_text_array
# 77457   0001-3773               ["0001-3773"]             [0001-3773]  \
# 55224   0001-3773               ["0001-3773"]             [0001-3773]
# 52174   0001-6071  ["0001-6071", "2094-9278"]  [0001-6071, 2094-9278]
# 40108   0001-6071   ["2094-9278","0001-6071"]  [2094-9278, 0001-6071]
# 58242   0001-6330               ["0001-6330"]             [0001-6330]
# ...           ...                         ...                     ...
# 35607   3033-3652  ["3033-3652", "3033-3652"]  [3033-3652, 3033-3652]
# 7618    3046-4986  ["3046-4986", "3046-4986"]  [3046-4986, 3046-4986]
# 55418   3046-9430  ["3046-9430", "3046-9430"]  [3046-9430, 3046-9430]
# 35562   8756-3452               ["8756-3452"]             [8756-3452]
# 119802  8756-3452               ["8756-3452"]             [8756-3452]
#
#            type country_code
# 77457   journal         None  \
# 55224   journal         None
# 52174   journal         None
# 40108   journal           PH
# 58242   journal         None
# ...         ...          ...
# 35607   journal         None
# 7618    journal         None
# 55418   journal         None
# 35562   journal           US
# 119802  journal         None
#
#                                          alternate_titles  publisher_id
# 77457                                                  []           NaN  \
# 55224                                                  []           NaN
# 52174                                                  []  4.310320e+09
# 40108               [The National Health Science journal]  4.310320e+09
# 58242                                                  []           NaN
# ...                                                   ...           ...
# 35607                                                None           NaN
# 7618                                                 None           NaN
# 55418                                                None           NaN
# 35562   [Yearbook of pulmonary disease, Pulmonary dise...  4.310321e+09
# 119802                                                 []  4.310321e+09
#
#         works_count
# 77457          84.0
# 55224         326.0
# 52174        1369.0
# 40108         173.0
# 58242        3794.0
# ...             ...
# 35607           5.0
# 7618            6.0
# 55418           0.0
# 35562           0.0
# 119802       1474.0
#
# [11226 rows x 10 columns]

# %%
from models.source import DELETED_SOURCE_ID
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 from models.source import DELETED_SOURCE_ID
#
# ImportError: cannot import name 'DELETED_SOURCE_ID' from 'models.source' (/home/hasone/code/ourresearch/openalex-guts/cleanup/notebooks/../../models/source.py)

# %%
DELETED_SOURCE_ID = 4317411217

# %%
# %%time
invalid = df_issnl_file[df_issnl_file['valid_issns'].isna()]
try:
    num_updated = 0
    for issn in tqdm(invalid['issns'].values, total=len(invalid)):
        now = datetime.now(timezone.utc).isoformat()
        q_source = db.session.query(Source).filter_by(merge_into_id=None).filter_by(issn=issn)
        for source in q_source.all():
            source.merge_into_id = DELETED_SOURCE_ID
            source.merge_into_date = now
            source.updated_date = now

            db.session.add(source)

            note = f"invalid issn {issn}"
            sq = """INSERT INTO issn_audit_20240321.update5
                    (source_id, updated_date, merge_into_id, note)
                    VALUES(:source_id, :now, :merge_into_id, :note);"""
            db.session.execute(text(sq), {
                'source_id': source.id,
                'now': now,
                'merge_into_id': DELETED_SOURCE_ID,
                'note': note,
            })
            num_updated += 1
    db.session.commit()
    print(f"{num_updated} updated")
finally:
    db.session.close()
# Out:
# 100%|██████████| 1518/1518 [06:04<00:00,  4.16it/s]
# 770 updated
# CPU times: user 13.2 s, sys: 602 ms, total: 13.8 s
# Wall time: 6min 18s

# %%
# %%time
try:
    num_updated = 0
    for issn in tqdm(invalid['issns'].values, total=len(invalid)):
        sq = """update issn_audit_20240321.issn_ic_datafile_202402 set resolved = true
            where "submitted_1348-0278" = :issn"""
        db.session.execute(text(sq), {
            'issn': issn,
        })
    db.session.commit()
except:
    db.session.close()
# Out:
# 100%|██████████| 1518/1518 [01:20<00:00, 18.85it/s]
# CPU times: user 1.26 s, sys: 236 ms, total: 1.5 s
# Wall time: 1min 20s

# %%
# %%time
url = "https://api.openalex.org/sources"
params = {
    'mailto': 'jportenoy@ourresearch.org',
    'group_by': 'issn',
}
data = []
for r in paginate_openalex(url, params=params):
    data.extend(r.json()['group_by'])
# Out:
# CPU times: user 8.66 s, sys: 288 ms, total: 8.95 s
# Wall time: 4min 32s

# %%
df_sources = pd.DataFrame(data)
_rename = {
    'key': 'issn',
    'count': 'num_sources_in_openalex',
}
df_openalex_issn_sources_count = df_sources.rename(columns=_rename).drop(columns=['key_display_name'])

# %%
df_openalex_issn_sources_count['num_sources_in_openalex'].value_counts()
# Out:
# num_sources_in_openalex
# 1    209737
# 2      8239
# 3       149
# 4         6
# 5         2
# Name: count, dtype: int64

# %%
sq = """SELECT "index", "submitted_1348-0278", issn, issnl, category, medium, frequency, country, center, "language", "start", "end", title, "comment", resolved
FROM issn_audit_20240321.issn_ic_datafile_202402;"""
df_file_simple = pd.read_sql_query(sq, db.engine)

# %%
df_issn_to_issnl = pd.read_sql_query("""select * from mid.journal_issn_to_issnl""", db.engine)

# %%
issn_to_issnl = df_issn_to_issnl.set_index('issn', verify_integrity=True)['issnl']

# %%
df_mult = df_openalex_issn_sources_count[df_openalex_issn_sources_count['num_sources_in_openalex']>1]
len(df_mult)
# Out:
# 8396

# %%
df_mult['issnl'] = df_mult['issn'].map(issn_to_issnl)
# Out:
# /tmp/ipykernel_32432/988665095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mult['issnl'] = df_mult['issn'].map(issn_to_issnl)

# %%
df_mult['is_issnl'] = df_mult['issn'] == df_mult['issnl']
# Out:
# /tmp/ipykernel_32432/2878915709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mult['is_issnl'] = df_mult['issn'] == df_mult['issnl']

# %%
df_mult['is_issnl'].value_counts()
# Out:
# is_issnl
# True     4220
# False    4176
# Name: count, dtype: int64

# %%
df_mult[df_mult['is_issnl']==False]
# Out:
#              issn  num_sources_in_openalex      issnl  is_issnl
# 2126    0012-0200                        2  1864-0303     False
# 3201    0018-9855                        2  0016-9420     False
# 3402    0020-2460                        2  2973-7842     False
# 6496    0035-2047                        2  3001-5898     False
# 7476    0040-7550                        3  2212-0521     False
# ...           ...                      ...        ...       ...
# 216413  3009-7770                        2  1110-7774     False
# 216415  3009-7835                        2  1110-8460     False
# 216417  3009-7886                        2  3009-7487     False
# 216636  3024-8671                        2  0854-9559     False
# 217076  3025-9606                        2  3025-6984     False
#
# [4176 rows x 4 columns]

# %%
issn_to_issnl[issn_to_issnl=='0016-9420']
# Out:
# issn
# 0016-9420    0016-9420
# 0018-9855    0016-9420
# 0435-8600    0016-9420
# 2195-0237    0016-9420
# Name: issnl, dtype: object

# %%
df_midjournal[df_midjournal['issn']=='0016-9420']
# Out:
#         journal_id                                       display_name
# 249631  1002663397  GRURRR. Gewerblicher Rechtsschutz und Urheberr...  \
#
#              issn                                              issns
# 249631  0016-9420  ["0016-9420", "0018-9855", "0435-8600", "2195-...  \
#
#                                     issns_text_array     type country_code
# 249631  [0016-9420, 0018-9855, 0435-8600, 2195-0237]  journal           DE  \
#
#        alternate_titles  publisher_id  works_count
# 249631           [GRUR]           NaN         29.0

# %%
df_midjournal[df_midjournal['issn']=='0018-9855']
# Out:
#        journal_id                                       display_name
# 17428     4695008  IIC - International Review of Intellectual Pro...  \
#
#             issn                       issns        issns_text_array     type
# 17428  0018-9855  ["2195-0237", "0018-9855"]  [2195-0237, 0018-9855]  journal  \
#
#       country_code                                   alternate_titles
# 17428           DE  [International review of intellectual property...  \
#
#        publisher_id  works_count
# 17428  4.310320e+09       1420.0

# %%
def get_all_sources_db(issn, session):
    sources1 = session.query(Source).options(Load(Source).lazyload('*')).filter_by(merge_into_id=None).filter_by(issn=issn).all()
    sources2 = session.query(Source).options(Load(Source).lazyload('*')).filter_by(merge_into_id=None).filter(Source.issns.contains(issn)).all()
    return set(sources1 + sources2)

# %%
issn = '0018-9855'
sources = get_all_sources_db(issn, db.session)

# %%
sources
# Out:
# {<Source ( http://localhost:5007/S1002663397?apiurls ) 1002663397 GRURRR. Gewerblicher Rechtsschutz und Urheberrecht, Rechtsprechungs-Report/GRUR-DVD/GRUR-CD/IIC/Gewerblicher Rechtsschutz und Urheberrecht/Gewerblicher Rechtsschutz und Urheberrecht. Internationaler Teil>,
#  <Source ( http://localhost:5007/S4695008?apiurls ) 4695008 IIC - International Review of Intellectual Property and Competition Law>}

# %%
df_mult['title'] = df_mult['issn'].map(df_issnl_file.set_index('issns', verify_integrity=True)['cluster_title'])
# Out:
# /tmp/ipykernel_32432/241424485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mult['title'] = df_mult['issn'].map(df_issnl_file.set_index('issns', verify_integrity=True)['cluster_title'])

# %%
title = df_mult[df_mult['issn']==issn].iloc[0]['title']

# %%
for source in sources:
    fuzzratio = rapidfuzz.fuzz.ratio(source.display_name, title, processor=rapidfuzz.utils.default_process)
    print(fuzzratio)
# Out:
# 100.0
# 29.92700729927007

# %%
try:
    dups_data = {}
    num_sources_verify = []
    works_count_map = df_midjournal.set_index('journal_id', verify_integrity=True)['works_count']
    for issn, row in tqdm(df_mult.set_index('issn', verify_integrity=True).iterrows(), total=len(df_mult)):
        this_issn_data = []
        sources = get_all_sources_db(issn, db.session)
        num_sources_verify.append({
            'issn': issn,
            'num_sources_in_openalex': row['num_sources_in_openalex'],
            'num_sources_db': len(sources),
        })
        for source in sources:
            fuzzratio = rapidfuzz.fuzz.ratio(source.display_name, row['title'], processor=rapidfuzz.utils.default_process)
            this_issn_data.append({
                'source_id': source.id,
                'fuzzratio': fuzzratio,
                'works_count': works_count_map[source.id]
            })
        dups_data[issn] = this_issn_data
finally:
    db.session.close()
# Out:
# 100%|██████████| 8396/8396 [13:27<00:00, 10.40it/s]

# %%
dups_data
# Out:
# {'0001-3773': [{'source_id': 4306504666,
#    'fuzzratio': 100.0,
#    'works_count': 84.0},
#   {'source_id': 4306504665, 'fuzzratio': 100.0, 'works_count': 326.0}],
#  '0001-6071': [{'source_id': 4210231482,
#    'fuzzratio': 65.67164179104478,
#    'works_count': 173.0},
#   {'source_id': 4306500404,
#    'fuzzratio': 65.67164179104478,
#    'works_count': 1369.0}],
#  '0001-6330': [{'source_id': 4306500432,
#    'fuzzratio': 100.0,
#    'works_count': 3794.0},
#   {'source_id': 2754219712, 'fuzzratio': 100.0, 'works_count': 75.0}],
#  '0001-6365': [{'source_id': 4306500438,
#    'fuzzratio': 100.0,
#    'works_count': 833.0},
#   {'source_id': 4306500439, 'fuzzratio': 100.0, 'works_count': 765.0}],
#  '0001-7302': [{'source_id': 4306500610,
#    'fuzzratio': 23.529411764705888,
#    'works_count': 149.0},
#   {'source_id': 4306500609,
#    'fuzzratio': 23.529411764705888,
#    'works_count': 2132.0}],
#  '0001-7884': [{'source_id': 43570703,
#    'fuzzratio': 100.0,
#    'works_count': 258.0},
#   {'source_id': 50311296,
#    'fuzzratio': 38.095238095238095,
#    'works_count': 1473.0}],
#  '0002-0427': [{'source_id': 4306500900,
#    'fuzzratio': 100.0,
#    'works_count': 25.0},
#   {'source_id': 4210172701,
#    'fuzzratio': 91.89189189189189,
#    'works_count': 42.0}],
#  '0002-1474': [{'source_id': 2764635152,
#    'fuzzratio': 95.1219512195122,
#    'works_count': 569.0},
#   {'source_id': 4210172420, 'fuzzratio': 100.0, 'works_count': 2.0}],
#  '0002-1873': [{'source_id': 4306501015,
#    'fuzzratio': 90.47619047619048,
#    'works_count': 177.0},
#   {'source_id': 4210176332,
#    'fuzzratio': 77.77777777777779,
#    'works_count': 758.0}],
#  '0002-3337': [{'source_id': 4306540506,
#    'fuzzratio': 3.7735849056603765,
#    'works_count': 210.0},
#   {'source_id': 4210207145, 'fuzzratio': 100.0, 'works_count': 687.0}],
#  '0002-3515': [{'source_id': 4306539272,
#    'fuzzratio': 14.035087719298245,
#    'works_count': 170.0},
#   {'source_id': 4210214448, 'fuzzratio': 100.0, 'works_count': 678.0}],
#  '0002-3752': [{'source_id': 4306507985,
#    'fuzzratio': 97.77777777777777,
#    'works_count': 245.0},
#   {'source_id': 4210167899,
#    'fuzzratio': 97.77777777777777,
#    'works_count': 4393.0}],
#  '0002-5216': [{'source_id': 4306501361,
#    'fuzzratio': 25.0,
#    'works_count': 589.0},
#   {'source_id': 4210177678, 'fuzzratio': 100.0, 'works_count': 364.0}],
#  '0002-5275': [{'source_id': 4210225013,
#    'fuzzratio': 100.0,
#    'works_count': 640.0},
#   {'source_id': 4306501376, 'fuzzratio': 100.0, 'works_count': 230.0}],
#  '0002-7138': [{'source_id': 4210208274,
#    'fuzzratio': 100.0,
#    'works_count': 2355.0},
#   {'source_id': 142481036, 'fuzzratio': 100.0, 'works_count': 8.0}],
#  '0002-8533': [{'source_id': 2764582485,
#    'fuzzratio': 98.96907216494846,
#    'works_count': 476.0},
#   {'source_id': 112560388,
#    'fuzzratio': 34.66666666666667,
#    'works_count': 34.0}],
#  '0003-1062': [{'source_id': 4210217549,
#    'fuzzratio': 100.0,
#    'works_count': 232.0},
#   {'source_id': 2764541395, 'fuzzratio': 100.0, 'works_count': 8862.0}],
#  '0003-3480': [{'source_id': 52870972,
#    'fuzzratio': 62.4113475177305,
#    'works_count': 658.0},
#   {'source_id': 4210193057,
#    'fuzzratio': 62.4113475177305,
#    'works_count': 0.0}],
#  '0003-5130': [{'source_id': 4210207874,
#    'fuzzratio': 63.1578947368421,
#    'works_count': 442.0},
#   {'source_id': 2764546465,
#    'fuzzratio': 29.268292682926834,
#    'works_count': 5.0}],
#  '0003-9438': [{'source_id': 4306502850,
#    'fuzzratio': 61.53846153846154,
#    'works_count': 128.0},
#   {'source_id': 4210199360,
#    'fuzzratio': 57.57575757575757,
#    'works_count': 1553.0}],
#  '0004-0177': [{'source_id': 4306502862,
#    'fuzzratio': 100.0,
#    'works_count': 200.0},
#   {'source_id': 4210219257, 'fuzzratio': 100.0, 'works_count': 518.0}],
#  '0004-0304': [{'source_id': 4210196618,
#    'fuzzratio': 100.0,
#    'works_count': 613.0},
#   {'source_id': 4306502877, 'fuzzratio': 100.0, 'works_count': 1132.0}],
#  '0004-0452': [{'source_id': 4306502891,
#    'fuzzratio': 100.0,
#    'works_count': 546.0},
#   {'source_id': 4210174217, 'fuzzratio': 100.0, 'works_count': 72.0}],
#  '0004-0584': [{'source_id': 4306502933,
#    'fuzzratio': 64.70588235294117,
#    'works_count': 3.0},
#   {'source_id': 4210203377,
#    'fuzzratio': 62.745098039215684,
#    'works_count': 91.0}],
#  '0004-0665': [{'source_id': 4306502954,
#    'fuzzratio': 100.0,
#    'works_count': 16.0},
#   {'source_id': 4306502955, 'fuzzratio': 100.0, 'works_count': 118.0}],
#  '0004-136X': [{'source_id': 2764413910,
#    'fuzzratio': 97.77777777777777,
#    'works_count': 5748.0},
#   {'source_id': 4210198271,
#    'fuzzratio': 97.77777777777777,
#    'works_count': 0.0}],
#  '0004-2927': [{'source_id': 4210175234,
#    'fuzzratio': 65.38461538461539,
#    'works_count': 253.0},
#   {'source_id': 4306503145,
#    'fuzzratio': 65.38461538461539,
#    'works_count': 249.0}],
#  '0004-8291': [{'source_id': 4210180267,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 124240608, 'fuzzratio': 100.0, 'works_count': 5382.0}],
#  '0004-9999': [{'source_id': 4210201742,
#    'fuzzratio': 52.94117647058824,
#    'works_count': 1310.0},
#   {'source_id': 2764997198,
#    'fuzzratio': 92.47311827956989,
#    'works_count': 0.0}],
#  '0005-2531': [{'source_id': 4306503932,
#    'fuzzratio': 50.0,
#    'works_count': 243.0},
#   {'source_id': 4210203337,
#    'fuzzratio': 65.75342465753424,
#    'works_count': 397.0}],
#  '0005-805X': [{'source_id': 4210205621,
#    'fuzzratio': 50.98039215686274,
#    'works_count': 615.0},
#   {'source_id': 4210240689, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0005-9021': [{'source_id': 4210181987,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4306504167, 'fuzzratio': 100.0, 'works_count': 13423.0}],
#  '0006-6583': [{'source_id': 4306504831,
#    'fuzzratio': 100.0,
#    'works_count': 127.0},
#   {'source_id': 4306504832, 'fuzzratio': 100.0, 'works_count': 96.0}],
#  '0007-019X': [{'source_id': 4306504956,
#    'fuzzratio': 91.89189189189189,
#    'works_count': 32.0},
#   {'source_id': 4306504955,
#    'fuzzratio': 91.89189189189189,
#    'works_count': 9.0}],
#  '0007-0971': [{'source_id': 4210207872,
#    'fuzzratio': 100.0,
#    'works_count': 2821.0},
#   {'source_id': 180551301, 'fuzzratio': 100.0, 'works_count': 8.0}],
#  '0007-1528': [{'source_id': 33536187, 'fuzzratio': 100.0, 'works_count': 6.0},
#   {'source_id': 4210183658, 'fuzzratio': 100.0, 'works_count': 889.0}],
#  '0007-1536': [{'source_id': 152005885,
#    'fuzzratio': 100.0,
#    'works_count': 33.0},
#   {'source_id': 4210190916, 'fuzzratio': 100.0, 'works_count': 7188.0}],
#  '0007-9510': [{'source_id': 4306505448,
#    'fuzzratio': 64.0,
#    'works_count': 395.0},
#   {'source_id': 4306505447, 'fuzzratio': 64.0, 'works_count': 44.0}],
#  '0008-3755': [{'source_id': 152034145,
#    'fuzzratio': 61.904761904761905,
#    'works_count': 3944.0},
#   {'source_id': 4210187052,
#    'fuzzratio': 68.18181818181819,
#    'works_count': 10110.0}],
#  '0008-4115': [{'source_id': 4210206680,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 2764912672, 'fuzzratio': 100.0, 'works_count': 184.0}],
#  '0008-5006': [{'source_id': 4306505620,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4210193653, 'fuzzratio': 100.0, 'works_count': 2566.0}],
#  '0008-9664': [{'source_id': 4210173118,
#    'fuzzratio': 35.0,
#    'works_count': 1925.0},
#   {'source_id': 4306507115,
#    'fuzzratio': 44.96124031007752,
#    'works_count': 133.0}],
#  '0009-0573': [{'source_id': 4306505900,
#    'fuzzratio': 95.65217391304348,
#    'works_count': 1.0},
#   {'source_id': 4306505901,
#    'fuzzratio': 95.65217391304348,
#    'works_count': 134.0}],
#  '0009-9252': [{'source_id': 2751047093,
#    'fuzzratio': 50.0,
#    'works_count': 412.0},
#   {'source_id': 2764792256,
#    'fuzzratio': 18.867924528301884,
#    'works_count': 520.0}],
#  '0010-180X': [{'source_id': 4210196913,
#    'fuzzratio': 64.28571428571428,
#    'works_count': 5121.0},
#   {'source_id': 2764816892,
#    'fuzzratio': 23.809523809523814,
#    'works_count': 42.0}],
#  '0011-2232': [{'source_id': 4210238816,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 201847129, 'fuzzratio': 100.0, 'works_count': 260.0}],
#  '0012-0200': [{'source_id': 4210208436,
#    'fuzzratio': 8.139534883720934,
#    'works_count': 295.0},
#   {'source_id': 4210179063, 'fuzzratio': 100.0, 'works_count': 1158.0}],
#  '0012-4494': [{'source_id': 4210181865,
#    'fuzzratio': 65.11627906976744,
#    'works_count': 158.0},
#   {'source_id': 4306508241,
#    'fuzzratio': 65.11627906976744,
#    'works_count': 1457.0}],
#  '0012-9623': [{'source_id': 4210178044,
#    'fuzzratio': 100.0,
#    'works_count': 4954.0},
#   {'source_id': 205499867, 'fuzzratio': 100.0, 'works_count': 432.0}],
#  '0013-0583': [{'source_id': 4306508707,
#    'fuzzratio': 100.0,
#    'works_count': 81.0},
#   {'source_id': 4306508709, 'fuzzratio': 100.0, 'works_count': 581.0}],
#  '0013-273X': [{'source_id': 2764536942,
#    'fuzzratio': 20.895522388059707,
#    'works_count': 76.0},
#   {'source_id': 4210167946, 'fuzzratio': 100.0, 'works_count': 3206.0}],
#  '0013-8797': [{'source_id': 4306524045,
#    'fuzzratio': 100.0,
#    'works_count': 1194.0},
#   {'source_id': 4210224067, 'fuzzratio': 100.0, 'works_count': 1862.0}],
#  '0013-8851': [{'source_id': 4306509530,
#    'fuzzratio': 100.0,
#    'works_count': 143.0},
#   {'source_id': 4210212359, 'fuzzratio': 100.0, 'works_count': 11.0}],
#  '0014-1364': [{'source_id': 4306509823,
#    'fuzzratio': 100.0,
#    'works_count': 5.0},
#   {'source_id': 4306509824, 'fuzzratio': 100.0, 'works_count': 133.0}],
#  '0014-2158': [{'source_id': 4210174797,
#    'fuzzratio': 100.0,
#    'works_count': 1575.0},
#   {'source_id': 4306510054, 'fuzzratio': 100.0, 'works_count': 1013.0}],
#  '0014-6722': [{'source_id': 4210174386,
#    'fuzzratio': 94.44444444444444,
#    'works_count': 1009.0},
#   {'source_id': 4306526882,
#    'fuzzratio': 87.17948717948718,
#    'works_count': 17.0}],
#  '0015-1831': [{'source_id': 984545958,
#    'fuzzratio': 100.0,
#    'works_count': 265.0},
#   {'source_id': 947039656,
#    'fuzzratio': 89.47368421052632,
#    'works_count': 111.0}],
#  '0015-3214': [{'source_id': 4306510566,
#    'fuzzratio': 94.44444444444444,
#    'works_count': 234.0},
#   {'source_id': 4210195083,
#    'fuzzratio': 11.428571428571432,
#    'works_count': 397.0}],
#  '0015-3222': [{'source_id': 4210185918,
#    'fuzzratio': 100.0,
#    'works_count': 1858.0},
#   {'source_id': 4306510568,
#    'fuzzratio': 98.46153846153847,
#    'works_count': 174.0}],
#  '0015-3230': [{'source_id': 99252752,
#    'fuzzratio': 100.0,
#    'works_count': 1897.0},
#   {'source_id': 4210234764, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0015-542X': [{'source_id': 4210187998,
#    'fuzzratio': 100.0,
#    'works_count': 143.0},
#   {'source_id': 4306510634, 'fuzzratio': 100.0, 'works_count': 73.0}],
#  '0015-5454': [{'source_id': 4306510638,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4306510639, 'fuzzratio': 100.0, 'works_count': 157.0}],
#  '0015-5551': [{'source_id': 184478927,
#    'fuzzratio': 100.0,
#    'works_count': 9.0},
#   {'source_id': 4210178945, 'fuzzratio': 100.0, 'works_count': 1207.0}],
#  '0016-7592': [{'source_id': 4306511324,
#    'fuzzratio': 53.703703703703695,
#    'works_count': 83.0},
#   {'source_id': 4220651000,
#    'fuzzratio': 58.97435897435898,
#    'works_count': 39956.0}],
#  '0016-9714': [{'source_id': 4306511450,
#    'fuzzratio': 90.32258064516128,
#    'works_count': 162.0},
#   {'source_id': 2764899822,
#    'fuzzratio': 65.21739130434783,
#    'works_count': 126.0}],
#  '0018-439X': [{'source_id': 4210230076,
#    'fuzzratio': 100.0,
#    'works_count': 1270.0},
#   {'source_id': 4306512302, 'fuzzratio': 100.0, 'works_count': 568.0}],
#  '0018-6872': [{'source_id': 4306512355,
#    'fuzzratio': 100.0,
#    'works_count': 122.0},
#   {'source_id': 4210223277, 'fuzzratio': 100.0, 'works_count': 118.0}],
#  '0018-7216': [{'source_id': 2764805623,
#    'fuzzratio': 30.000000000000004,
#    'works_count': 3376.0},
#   {'source_id': 4210196938,
#    'fuzzratio': 64.86486486486487,
#    'works_count': 0.0}],
#  '0018-8646': [{'source_id': 106390105,
#    'fuzzratio': 100.0,
#    'works_count': 38.0},
#   {'source_id': 4210219925, 'fuzzratio': 100.0, 'works_count': 4717.0}],
#  '0018-974X': [{'source_id': 4306512882,
#    'fuzzratio': 100.0,
#    'works_count': 3831.0},
#   {'source_id': 4306512883, 'fuzzratio': 100.0, 'works_count': 383.0}],
#  '0018-9855': [{'source_id': 1002663397,
#    'fuzzratio': 100.0,
#    'works_count': 29.0},
#   {'source_id': 4695008,
#    'fuzzratio': 29.92700729927007,
#    'works_count': 1420.0}],
#  '0019-042X': [{'source_id': 2764731898,
#    'fuzzratio': 64.321608040201,
#    'works_count': 2034.0},
#   {'source_id': 15805073,
#    'fuzzratio': 67.64705882352942,
#    'works_count': 52.0}],
#  '0019-2341': [{'source_id': 170156043,
#    'fuzzratio': 32.20338983050848,
#    'works_count': 695.0},
#   {'source_id': 4210213007,
#    'fuzzratio': 51.85185185185186,
#    'works_count': 13222.0}],
#  '0019-3089': [{'source_id': 4210197774,
#    'fuzzratio': 100.0,
#    'works_count': 2555.0},
#   {'source_id': 2764378435, 'fuzzratio': 100.0, 'works_count': 17.0}],
#  '0020-2452': [{'source_id': 4210220920,
#    'fuzzratio': 100.0,
#    'works_count': 132.0},
#   {'source_id': 147296217, 'fuzzratio': 100.0, 'works_count': 33.0}],
#  '0020-2460': [{'source_id': 4306502812,
#    'fuzzratio': 72.22222222222221,
#    'works_count': 0.0},
#   {'source_id': 4393920123, 'fuzzratio': 100.0, 'works_count': 1.0}],
#  '0020-269X': [{'source_id': 2764563884,
#    'fuzzratio': 71.42857142857143,
#    'works_count': 1090.0},
#   {'source_id': 4210190786,
#    'fuzzratio': 71.42857142857143,
#    'works_count': 0.0}],
#  '0020-3653': [{'source_id': 4210198305,
#    'fuzzratio': 65.95744680851064,
#    'works_count': 1448.0},
#   {'source_id': 4306503107,
#    'fuzzratio': 65.95744680851064,
#    'works_count': 149.0}],
#  '0020-7101': [{'source_id': 4210229455,
#    'fuzzratio': 82.22222222222221,
#    'works_count': 1648.0},
#   {'source_id': 185809434, 'fuzzratio': 100.0, 'works_count': 1.0}],
#  '0020-7551': [{'source_id': 4210176357,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 61018360, 'fuzzratio': 100.0, 'works_count': 114.0}],
#  '0021-4027': [{'source_id': 97042997,
#    'fuzzratio': 93.33333333333333,
#    'works_count': 8126.0},
#   {'source_id': 2764803905,
#    'fuzzratio': 55.00000000000001,
#    'works_count': 276.0}],
#  '0021-4426': [{'source_id': 4210168067,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 5.0},
#   {'source_id': 2764955433,
#    'fuzzratio': 31.57894736842105,
#    'works_count': 3181.0}],
#  '0021-4876': [{'source_id': 4210173253,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 13988.0},
#   {'source_id': 106068469,
#    'fuzzratio': 34.09090909090909,
#    'works_count': 60.0}],
#  '0021-5139': [{'source_id': 4210193810,
#    'fuzzratio': 100.0,
#    'works_count': 1131.0},
#   {'source_id': 2754025768, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0021-5147': [{'source_id': 2764884928,
#    'fuzzratio': 27.848101265822788,
#    'works_count': 42.0},
#   {'source_id': 2764462303,
#    'fuzzratio': 24.615384615384617,
#    'works_count': 3067.0}],
#  '0021-5171': [{'source_id': 4306514856,
#    'fuzzratio': 27.450980392156865,
#    'works_count': 1092.0},
#   {'source_id': 2765076554,
#    'fuzzratio': 94.73684210526316,
#    'works_count': 173.0}],
#  '0021-7689': [{'source_id': 4210228867,
#    'fuzzratio': 46.846846846846844,
#    'works_count': 10438.0},
#   {'source_id': 6498875, 'fuzzratio': 81.11888111888112, 'works_count': 46.0}],
#  '0021-7867': [{'source_id': 4306504872,
#    'fuzzratio': 96.96969696969697,
#    'works_count': 59.0},
#   {'source_id': 4306504871,
#    'fuzzratio': 96.96969696969697,
#    'works_count': 0.0}],
#  '0022-0213': [{'source_id': 2764625199,
#    'fuzzratio': 98.46153846153847,
#    'works_count': 5.0},
#   {'source_id': 4210188674,
#    'fuzzratio': 98.46153846153847,
#    'works_count': 222.0}],
#  '0022-1716': [{'source_id': 4210208351,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 118325222, 'fuzzratio': 100.0, 'works_count': 574.0}],
#  '0022-1937': [{'source_id': 102099276,
#    'fuzzratio': 65.78947368421053,
#    'works_count': 97.0},
#   {'source_id': 4210211401,
#    'fuzzratio': 65.78947368421053,
#    'works_count': 1478.0}],
#  '0022-5088': [{'source_id': 78451586,
#    'fuzzratio': 100.0,
#    'works_count': 9252.0},
#   {'source_id': 4210208831, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0023-0243': [{'source_id': 2764606382,
#    'fuzzratio': 67.14285714285715,
#    'works_count': 13.0},
#   {'source_id': 4210214201,
#    'fuzzratio': 67.14285714285715,
#    'works_count': 1246.0}],
#  '0023-2149': [{'source_id': 2752393482,
#    'fuzzratio': 79.06976744186046,
#    'works_count': 3038.0},
#   {'source_id': 2764554217,
#    'fuzzratio': 79.06976744186046,
#    'works_count': 204.0}],
#  '0023-5830': [{'source_id': 4306517917,
#    'fuzzratio': 62.22222222222222,
#    'works_count': 3495.0},
#   {'source_id': 2764485282,
#    'fuzzratio': 62.22222222222222,
#    'works_count': 5.0}],
#  '0024-1415': [{'source_id': 4306518529,
#    'fuzzratio': 88.23529411764706,
#    'works_count': 123.0},
#   {'source_id': 4210239096, 'fuzzratio': 100.0, 'works_count': 1506.0}],
#  '0025-5270': [{'source_id': 4210219282,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 88278773, 'fuzzratio': 100.0, 'works_count': 127.0}],
#  '0025-6307': [{'source_id': 2764344921,
#    'fuzzratio': 100.0,
#    'works_count': 19.0},
#   {'source_id': 4210180357, 'fuzzratio': 100.0, 'works_count': 640.0}],
#  '0026-1165': [{'source_id': 4210180649,
#    'fuzzratio': 67.64705882352942,
#    'works_count': 0.0},
#   {'source_id': 2764910039,
#    'fuzzratio': 67.64705882352942,
#    'works_count': 9505.0}],
#  '0026-2005': [{'source_id': 4306519874,
#    'fuzzratio': 100.0,
#    'works_count': 63.0},
#   {'source_id': 4210234115, 'fuzzratio': 100.0, 'works_count': 81.0}],
#  '0027-4100': [{'source_id': 4210183126,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 35074681, 'fuzzratio': 100.0, 'works_count': 160.0}],
#  '0028-0615': [{'source_id': 4306520597,
#    'fuzzratio': 100.0,
#    'works_count': 89.0},
#   {'source_id': 4306520598, 'fuzzratio': 100.0, 'works_count': 812.0}],
#  '0028-2006': [{'source_id': 4210222329,
#    'fuzzratio': 100.0,
#    'works_count': 336.0},
#   {'source_id': 2736717633,
#    'fuzzratio': 78.37837837837837,
#    'works_count': 8.0}],
#  '0029-8131': [{'source_id': 4210176105,
#    'fuzzratio': 64.61538461538461,
#    'works_count': 0.0},
#   {'source_id': 2764687577,
#    'fuzzratio': 37.362637362637365,
#    'works_count': 1345.0}],
#  '0029-814X': [{'source_id': 4306521321,
#    'fuzzratio': 28.57142857142857,
#    'works_count': 824.0},
#   {'source_id': 4306521320,
#    'fuzzratio': 28.57142857142857,
#    'works_count': 858.0},
#   {'source_id': 4306521322,
#    'fuzzratio': 28.57142857142857,
#    'works_count': 222.0}],
#  '0030-5472': [{'source_id': 4306521659,
#    'fuzzratio': 55.55555555555556,
#    'works_count': 133.0},
#   {'source_id': 4210178598,
#    'fuzzratio': 55.55555555555556,
#    'works_count': 2436.0}],
#  '0030-7653': [{'source_id': 26073974,
#    'fuzzratio': 100.0,
#    'works_count': 3108.0},
#   {'source_id': 4306521864, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0031-6032': [{'source_id': 4306522356,
#    'fuzzratio': 53.333333333333336,
#    'works_count': 219.0},
#   {'source_id': 4210211928,
#    'fuzzratio': 76.05633802816901,
#    'works_count': 1087.0}],
#  '0031-6903': [{'source_id': 4210187371,
#    'fuzzratio': 100.0,
#    'works_count': 1.0},
#   {'source_id': 2764386467,
#    'fuzzratio': 19.672131147540984,
#    'works_count': 25125.0}],
#  '0031-9082': [{'source_id': 156848579,
#    'fuzzratio': 100.0,
#    'works_count': 5.0},
#   {'source_id': 4210230812, 'fuzzratio': 100.0, 'works_count': 1902.0}],
#  '0032-1877': [{'source_id': 31428200, 'fuzzratio': 100.0, 'works_count': 0.0},
#   {'source_id': 4210195085, 'fuzzratio': 100.0, 'works_count': 85.0}],
#  '0032-8979': [{'source_id': 4210172629,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 75408032, 'fuzzratio': 100.0, 'works_count': 101.0}],
#  '0033-9725': [{'source_id': 4306525365,
#    'fuzzratio': 66.14173228346456,
#    'works_count': 1173.0},
#   {'source_id': 4306525364,
#    'fuzzratio': 66.14173228346456,
#    'works_count': 73.0}],
#  '0034-3072': [{'source_id': 2764750034,
#    'fuzzratio': 100.0,
#    'works_count': 288.0},
#   {'source_id': 4210225676, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0034-6683': [{'source_id': 4210205061,
#    'fuzzratio': 100.0,
#    'works_count': 29.0},
#   {'source_id': 54638968, 'fuzzratio': 98.41269841269842, 'works_count': 0.0}],
#  '0034-7108': [{'source_id': 118988084,
#    'fuzzratio': 100.0,
#    'works_count': 987.0},
#   {'source_id': 4210191268, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0034-7191': [{'source_id': 4210185507,
#    'fuzzratio': 66.10169491525424,
#    'works_count': 352.0},
#   {'source_id': 4306526185,
#    'fuzzratio': 66.10169491525424,
#    'works_count': 233.0}],
#  '0034-7248': [{'source_id': 4306526203,
#    'fuzzratio': 100.0,
#    'works_count': 19.0},
#   {'source_id': 4306526204, 'fuzzratio': 100.0, 'works_count': 190.0}],
#  '0034-740X': [{'source_id': 4210172032,
#    'fuzzratio': 65.21739130434783,
#    'works_count': 459.0},
#   {'source_id': 4306526288,
#    'fuzzratio': 65.21739130434783,
#    'works_count': 62.0}],
#  '0034-7485': [{'source_id': 4306526422,
#    'fuzzratio': 100.0,
#    'works_count': 565.0},
#   {'source_id': 4306526423, 'fuzzratio': 100.0, 'works_count': 581.0}],
#  '0034-7612': [{'source_id': 4210228912,
#    'fuzzratio': 100.0,
#    'works_count': 1384.0},
#   {'source_id': 4306526540, 'fuzzratio': 100.0, 'works_count': 620.0}],
#  '0034-7639': [{'source_id': 4306526542,
#    'fuzzratio': 100.0,
#    'works_count': 1781.0},
#   {'source_id': 4210189553, 'fuzzratio': 100.0, 'works_count': 2390.0}],
#  '0034-7752': [{'source_id': 156983221,
#    'fuzzratio': 100.0,
#    'works_count': 3647.0},
#   {'source_id': 4210170583, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0034-8252': [{'source_id': 4306526761,
#    'fuzzratio': 52.52525252525253,
#    'works_count': 884.0},
#   {'source_id': 4306526760,
#    'fuzzratio': 52.52525252525253,
#    'works_count': 92.0}],
#  '0034-9690': [{'source_id': 4210221370,
#    'fuzzratio': 67.88990825688073,
#    'works_count': 0.0},
#   {'source_id': 2764717225,
#    'fuzzratio': 65.42056074766356,
#    'works_count': 1050.0}],
#  '0035-0958': [{'source_id': 4306528145,
#    'fuzzratio': 69.35483870967742,
#    'works_count': 656.0},
#   {'source_id': 4210205640,
#    'fuzzratio': 62.71186440677966,
#    'works_count': 991.0},
#   {'source_id': 4306528144,
#    'fuzzratio': 69.35483870967742,
#    'works_count': 90.0}],
#  '0035-1733': [{'source_id': 4210170923,
#    'fuzzratio': 100.0,
#    'works_count': 1201.0},
#   {'source_id': 4306528231, 'fuzzratio': 100.0, 'works_count': 1122.0}],
#  '0035-1768': [{'source_id': 9135594,
#    'fuzzratio': 100.0,
#    'works_count': 263.0},
#   {'source_id': 4210231195, 'fuzzratio': 100.0, 'works_count': 1158.0}],
#  '0035-2039': [{'source_id': 4210184375,
#    'fuzzratio': 64.93506493506493,
#    'works_count': 2633.0},
#   {'source_id': 4306528239,
#    'fuzzratio': 64.93506493506493,
#    'works_count': 651.0}],
#  '0035-2047': [{'source_id': 4393920186,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 73261239, 'fuzzratio': 96.2962962962963, 'works_count': 26.0}],
#  '0035-2195': [{'source_id': 4306528258,
#    'fuzzratio': 100.0,
#    'works_count': 1153.0},
#   {'source_id': 4306528257, 'fuzzratio': 100.0, 'works_count': 108.0},
#   {'source_id': 4306528256, 'fuzzratio': 100.0, 'works_count': 1221.0}],
#  '0035-2217': [{'source_id': 4306528263,
#    'fuzzratio': 100.0,
#    'works_count': 2741.0},
#   {'source_id': 4210238334, 'fuzzratio': 100.0, 'works_count': 6455.0}],
#  '0035-2403': [{'source_id': 4210179361,
#    'fuzzratio': 100.0,
#    'works_count': 1896.0},
#   {'source_id': 4306528294, 'fuzzratio': 100.0, 'works_count': 12151.0}],
#  '0035-2829': [{'source_id': 4306528334,
#    'fuzzratio': 96.2962962962963,
#    'works_count': 193.0},
#   {'source_id': 4210209056,
#    'fuzzratio': 88.88888888888889,
#    'works_count': 6701.0}],
#  '0035-2969': [{'source_id': 70949411,
#    'fuzzratio': 65.1685393258427,
#    'works_count': 5129.0},
#   {'source_id': 4210180269,
#    'fuzzratio': 65.1685393258427,
#    'works_count': 0.0}],
#  '0035-2985': [{'source_id': 4210183280,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 1245.0},
#   {'source_id': 4306528352,
#    'fuzzratio': 65.48672566371681,
#    'works_count': 173.0}],
#  '0035-3809': [{'source_id': 4306518190,
#    'fuzzratio': 97.14285714285714,
#    'works_count': 1294.0},
#   {'source_id': 4210188052,
#    'fuzzratio': 97.14285714285714,
#    'works_count': 138.0}],
#  '0035-3841': [{'source_id': 38817601,
#    'fuzzratio': 100.0,
#    'works_count': 12514.0},
#   {'source_id': 4210229261, 'fuzzratio': 100.0, 'works_count': 1677.0}],
#  '0035-449X': [{'source_id': 4306528508,
#    'fuzzratio': 100.0,
#    'works_count': 274.0},
#   {'source_id': 4306528509, 'fuzzratio': 100.0, 'works_count': 100.0}],
#  '0035-5054': [{'source_id': 4210168108,
#    'fuzzratio': 100.0,
#    'works_count': 102.0},
#   {'source_id': 66006601, 'fuzzratio': 100.0, 'works_count': 37.0}],
#  '0035-6093': [{'source_id': 4306528595,
#    'fuzzratio': 100.0,
#    'works_count': 92.0},
#   {'source_id': 4306528594, 'fuzzratio': 100.0, 'works_count': 1281.0}],
#  '0035-6190': [{'source_id': 4210174638,
#    'fuzzratio': 100.0,
#    'works_count': 67.0},
#   {'source_id': 4306528606, 'fuzzratio': 100.0, 'works_count': 189.0}],
#  '0035-6387': [{'source_id': 4306528628,
#    'fuzzratio': 100.0,
#    'works_count': 592.0},
#   {'source_id': 4306528627, 'fuzzratio': 100.0, 'works_count': 9.0}],
#  '0035-6697': [{'source_id': 4306528656,
#    'fuzzratio': 65.85365853658536,
#    'works_count': 92.0},
#   {'source_id': 4210178440,
#    'fuzzratio': 65.85365853658536,
#    'works_count': 186.0},
#   {'source_id': 4306528655,
#    'fuzzratio': 65.85365853658536,
#    'works_count': 1145.0}],
#  '0035-7030': [{'source_id': 4306528690,
#    'fuzzratio': 100.0,
#    'works_count': 3.0},
#   {'source_id': 4306528691, 'fuzzratio': 100.0, 'works_count': 164.0}],
#  '0035-7707': [{'source_id': 4306528754,
#    'fuzzratio': 100.0,
#    'works_count': 30.0},
#   {'source_id': 4210186998, 'fuzzratio': 100.0, 'works_count': 2609.0}],
#  '0035-8789': [{'source_id': 2764685102,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4210193928, 'fuzzratio': 100.0, 'works_count': 2084.0}],
#  '0036-147X': [{'source_id': 45217428,
#    'fuzzratio': 69.84126984126983,
#    'works_count': 32.0},
#   {'source_id': 4210187967,
#    'fuzzratio': 61.01694915254237,
#    'works_count': 0.0}],
#  '0037-2102': [{'source_id': 4306529642,
#    'fuzzratio': 100.0,
#    'works_count': 33.0},
#   {'source_id': 4306529643, 'fuzzratio': 100.0, 'works_count': 93.0}],
#  '0037-2188': [{'source_id': 4210190204,
#    'fuzzratio': 60.86956521739131,
#    'works_count': 389.0},
#   {'source_id': 2764965336,
#    'fuzzratio': 59.09090909090908,
#    'works_count': 127.0}],
#  '0037-8755': [{'source_id': 4306504824,
#    'fuzzratio': 100.0,
#    'works_count': 100.0},
#   {'source_id': 4210182737, 'fuzzratio': 100.0, 'works_count': 2.0}],
#  '0037-9360': [{'source_id': 4210183662,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4306505095,
#    'fuzzratio': 97.72727272727273,
#    'works_count': 25.0}],
#  '0037-9395': [{'source_id': 4306502181,
#    'fuzzratio': 100.0,
#    'works_count': 153.0},
#   {'source_id': 4306502180, 'fuzzratio': 100.0, 'works_count': 1043.0}],
#  '0037-9565': [{'source_id': 4210232837,
#    'fuzzratio': 100.0,
#    'works_count': 22.0},
#   {'source_id': 4306505107, 'fuzzratio': 100.0, 'works_count': 636.0}],
#  '0037-9778': [{'source_id': 4210175519,
#    'fuzzratio': 100.0,
#    'works_count': 1136.0},
#   {'source_id': 2764585358, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0038-3317': [{'source_id': 2754208863,
#    'fuzzratio': 100.0,
#    'works_count': 126.0},
#   {'source_id': 2755406093,
#    'fuzzratio': 54.86725663716814,
#    'works_count': 487.0}],
#  '0038-4585': [{'source_id': 2764909103,
#    'fuzzratio': 98.18181818181819,
#    'works_count': 0.0},
#   {'source_id': 4210174775,
#    'fuzzratio': 62.06896551724138,
#    'works_count': 1493.0}],
#  '0038-5875': [{'source_id': 4210228232,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 2764385765, 'fuzzratio': 100.0, 'works_count': 691.0}],
#  '0039-2618': [{'source_id': 4306530991,
#    'fuzzratio': 100.0,
#    'works_count': 694.0},
#   {'source_id': 4306530990, 'fuzzratio': 100.0, 'works_count': 551.0}],
#  '0039-2871': [{'source_id': 4210189634,
#    'fuzzratio': 100.0,
#    'works_count': 3201.0},
#   {'source_id': 178103872,
#    'fuzzratio': 98.11320754716981,
#    'works_count': 0.0}],
#  '0039-3525': [{'source_id': 2764387647,
#    'fuzzratio': 100.0,
#    'works_count': 3.0},
#   {'source_id': 4210234015, 'fuzzratio': 100.0, 'works_count': 211.0}],
#  '0039-3541': [{'source_id': 2764493093,
#    'fuzzratio': 48.484848484848484,
#    'works_count': 1930.0},
#   {'source_id': 4306531159, 'fuzzratio': 100.0, 'works_count': 355.0}],
#  '0039-6761': [{'source_id': 4210206439,
#    'fuzzratio': 100.0,
#    'works_count': 463.0},
#   {'source_id': 4306531407, 'fuzzratio': 100.0, 'works_count': 401.0}],
#  '0040-2486': [{'source_id': 134467508,
#    'fuzzratio': 98.7012987012987,
#    'works_count': 168.0},
#   {'source_id': 4210167519, 'fuzzratio': 95.0, 'works_count': 366.0}],
#  '0040-3636': [{'source_id': 4210190991,
#    'fuzzratio': 0.0,
#    'works_count': 1418.0},
#   {'source_id': 4306531852,
#    'fuzzratio': 93.33333333333333,
#    'works_count': 103.0}],
#  '0040-5612': [{'source_id': 4210235932,
#    'fuzzratio': 100.0,
#    'works_count': 155.0},
#   {'source_id': 4306532597, 'fuzzratio': 100.0, 'works_count': 267.0}],
#  '0040-7550': [{'source_id': 4393918324,
#    'fuzzratio': 100.0,
#    'works_count': 41.0},
#   {'source_id': 33907774,
#    'fuzzratio': 64.42953020134227,
#    'works_count': 653.0},
#   {'source_id': 4210188092,
#    'fuzzratio': 65.33333333333333,
#    'works_count': 72.0}],
#  '0041-1051': [{'source_id': 2765065909,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4210184516, 'fuzzratio': 100.0, 'works_count': 701.0}],
#  '0041-2945': [{'source_id': 4306533326,
#    'fuzzratio': 100.0,
#    'works_count': 161.0},
#   {'source_id': 4306533325, 'fuzzratio': 100.0, 'works_count': 41.0}],
#  '0041-3011': [{'source_id': 175963831,
#    'fuzzratio': 55.88235294117647,
#    'works_count': 661.0},
#   {'source_id': 4210185843,
#    'fuzzratio': 61.9718309859155,
#    'works_count': 0.0}],
#  '0041-4751': [{'source_id': 4306533597,
#    'fuzzratio': 100.0,
#    'works_count': 1090.0},
#   {'source_id': 4210210686, 'fuzzratio': 100.0, 'works_count': 791.0}],
#  '0041-5553': [{'source_id': 4210201502,
#    'fuzzratio': 100.0,
#    'works_count': 5548.0},
#   {'source_id': 130594570,
#    'fuzzratio': 96.49122807017544,
#    'works_count': 9.0}],
#  '0042-5435': [{'source_id': 4306534265,
#    'fuzzratio': 100.0,
#    'works_count': 2225.0},
#   {'source_id': 4306534266, 'fuzzratio': 100.0, 'works_count': 834.0}],
#  '0042-8426': [{'source_id': 4306534453,
#    'fuzzratio': 100.0,
#    'works_count': 344.0},
#   {'source_id': 4210193792,
#    'fuzzratio': 9.999999999999998,
#    'works_count': 1027.0}],
#  '0042-8752': [{'source_id': 4210225751,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4306534555,
#    'fuzzratio': 97.2972972972973,
#    'works_count': 1045.0}],
#  '0042-8809': [{'source_id': 2764873491,
#    'fuzzratio': 57.14285714285714,
#    'works_count': 19.0},
#   {'source_id': 2753587411,
#    'fuzzratio': 83.63636363636364,
#    'works_count': 362.0}],
#  '0042-899X': [{'source_id': 4306534565,
#    'fuzzratio': 100.0,
#    'works_count': 251.0},
#   {'source_id': 4306534566, 'fuzzratio': 100.0, 'works_count': 947.0}],
#  '0043-5414': [{'source_id': 4210192797,
#    'fuzzratio': 82.25806451612902,
#    'works_count': 216.0},
#   {'source_id': 4306534801,
#    'fuzzratio': 82.25806451612902,
#    'works_count': 123.0}],
#  '0044-3468': [{'source_id': 122457620,
#    'fuzzratio': 54.36893203883495,
#    'works_count': 11.0},
#   {'source_id': 4306535637, 'fuzzratio': 100.0, 'works_count': 15.0}],
#  '0044-5177': [{'source_id': 4210232257,
#    'fuzzratio': 47.82608695652174,
#    'works_count': 20.0},
#   {'source_id': 4306536271, 'fuzzratio': 100.0, 'works_count': 13.0}],
#  '0044-5193': [{'source_id': 4210193462,
#    'fuzzratio': 41.9047619047619,
#    'works_count': 0.0},
#   {'source_id': 4306536272, 'fuzzratio': 100.0, 'works_count': 16.0}],
#  '0044-5983': [{'source_id': 4306500290,
#    'fuzzratio': 100.0,
#    'works_count': 109.0},
#   {'source_id': 4210197340, 'fuzzratio': 100.0, 'works_count': 3200.0}],
#  '0044-8753': [{'source_id': 4306502959,
#    'fuzzratio': 100.0,
#    'works_count': 852.0},
#   {'source_id': 4210182607, 'fuzzratio': 100.0, 'works_count': 319.0}],
#  '0045-0642': [{'source_id': 4210203661,
#    'fuzzratio': 98.59154929577466,
#    'works_count': 231.0},
#   {'source_id': 106597503,
#    'fuzzratio': 98.59154929577466,
#    'works_count': 9.0}],
#  '0045-5075': [{'source_id': 4210222761,
#    'fuzzratio': 100.0,
#    'works_count': 32.0},
#   {'source_id': 4306505615, 'fuzzratio': 100.0, 'works_count': 15.0}],
#  '0045-8732': [{'source_id': 39520412,
#    'fuzzratio': 65.85365853658536,
#    'works_count': 0.0},
#   {'source_id': 4210204602,
#    'fuzzratio': 65.85365853658536,
#    'works_count': 3029.0}],
#  '0046-2616': [{'source_id': 4210178419,
#    'fuzzratio': 100.0,
#    'works_count': 2447.0},
#   {'source_id': 4306510007, 'fuzzratio': 95.0, 'works_count': 323.0}],
#  '0046-2659': [{'source_id': 4306510059,
#    'fuzzratio': 64.28571428571428,
#    'works_count': 148.0},
#   {'source_id': 4210187869,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 283.0}],
#  '0046-9777': [{'source_id': 4210175492,
#    'fuzzratio': 97.14285714285714,
#    'works_count': 4123.0},
#   {'source_id': 176230755,
#    'fuzzratio': 71.42857142857143,
#    'works_count': 3.0}],
#  '0047-2263': [{'source_id': 2764426614,
#    'fuzzratio': 98.46153846153847,
#    'works_count': 161.0},
#   {'source_id': 4210225809,
#    'fuzzratio': 91.80327868852459,
#    'works_count': 116.0}],
#  '0048-3664': [{'source_id': 4210210882,
#    'fuzzratio': 68.49315068493152,
#    'works_count': 5173.0},
#   {'source_id': 7263815, 'fuzzratio': 68.49315068493152, 'works_count': 80.0}],
#  '0048-377X': [{'source_id': 4210222012,
#    'fuzzratio': 59.04761904761905,
#    'works_count': 47.0},
#   {'source_id': 4210206543, 'fuzzratio': 100.0, 'works_count': 76.0}],
#  '0048-7163': [{'source_id': 4306533271,
#    'fuzzratio': 65.67164179104478,
#    'works_count': 136.0},
#   {'source_id': 4210184101,
#    'fuzzratio': 65.67164179104478,
#    'works_count': 487.0}],
#  '0048-7457': [{'source_id': 4210210012,
#    'fuzzratio': 100.0,
#    'works_count': 40.0},
#   {'source_id': 152181233,
#    'fuzzratio': 70.27027027027026,
#    'works_count': 0.0}],
#  '0048-7562': [{'source_id': 200132817,
#    'fuzzratio': 100.0,
#    'works_count': 9.0},
#   {'source_id': 4210210608, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0065-0536': [{'source_id': 4306506711,
#    'fuzzratio': 76.6839378238342,
#    'works_count': 2483.0},
#   {'source_id': 57474432,
#    'fuzzratio': 76.04166666666666,
#    'works_count': 11875.0}],
#  '0065-1478': [{'source_id': 4306500458,
#    'fuzzratio': 100.0,
#    'works_count': 36.0},
#   {'source_id': 4306500459, 'fuzzratio': 100.0, 'works_count': 603.0}],
#  '0066-6874': [{'source_id': 4306502967,
#    'fuzzratio': 66.18705035971223,
#    'works_count': 231.0},
#   {'source_id': 4210196793,
#    'fuzzratio': 66.18705035971223,
#    'works_count': 67.0}],
#  '0067-8546': [{'source_id': 158463809,
#    'fuzzratio': 28.000000000000004,
#    'works_count': 56.0},
#   {'source_id': 4306504315, 'fuzzratio': 100.0, 'works_count': 952.0},
#   {'source_id': 4306504316, 'fuzzratio': 100.0, 'works_count': 169.0}],
#  '0067-9615': [{'source_id': 4210213026,
#    'fuzzratio': 65.85365853658536,
#    'works_count': 372.0},
#   {'source_id': 4306504595,
#    'fuzzratio': 65.85365853658536,
#    'works_count': 956.0}],
#  '0068-1385': [{'source_id': 4210189543,
#    'fuzzratio': 100.0,
#    'works_count': 500.0},
#   {'source_id': 2764485589, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0071-1276': [{'source_id': 180636381,
#    'fuzzratio': 100.0,
#    'works_count': 62.0},
#   {'source_id': 4210197822, 'fuzzratio': 100.0, 'works_count': 1517.0}],
#  '0074-1612': [{'source_id': 4210218337,
#    'fuzzratio': 100.0,
#    'works_count': 9.0},
#   {'source_id': 2764891740, 'fuzzratio': 100.0, 'works_count': 109.0}],
#  '0074-1809': [{'source_id': 187173200,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 41.0},
#   {'source_id': 4306531450,
#    'fuzzratio': 33.9622641509434,
#    'works_count': 19393.0}],
#  '0074-2740': [{'source_id': 966329322,
#    'fuzzratio': 62.745098039215684,
#    'works_count': 83.0},
#   {'source_id': 4210177591, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0077-5762': [{'source_id': 4210193383,
#    'fuzzratio': 97.70992366412213,
#    'works_count': 357.0},
#   {'source_id': 107003806,
#    'fuzzratio': 95.9349593495935,
#    'works_count': 83.0}],
#  '0079-726X': [{'source_id': 4306518153,
#    'fuzzratio': 98.11320754716981,
#    'works_count': 121.0},
#   {'source_id': 4210223661,
#    'fuzzratio': 98.11320754716981,
#    'works_count': 516.0}],
#  '0080-3715': [{'source_id': 4210168225,
#    'fuzzratio': 24.0,
#    'works_count': 718.0},
#   {'source_id': 4306528758,
#    'fuzzratio': 53.333333333333336,
#    'works_count': 14.0}],
#  '0080-4436': [{'source_id': 107655702,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4210180694, 'fuzzratio': 100.0, 'works_count': 298.0}],
#  '0081-3834': [{'source_id': 4306530791,
#    'fuzzratio': 100.0,
#    'works_count': 91.0},
#   {'source_id': 4210199994, 'fuzzratio': 100.0, 'works_count': 2008.0}],
#  '0082-4313': [{'source_id': 4306532949,
#    'fuzzratio': 57.425742574257434,
#    'works_count': 170.0},
#   {'source_id': 4306532950,
#    'fuzzratio': 57.425742574257434,
#    'works_count': 231.0}],
#  '0082-6340': [{'source_id': 4210226355,
#    'fuzzratio': 100.0,
#    'works_count': 62.0},
#   {'source_id': 4210192418, 'fuzzratio': 100.0, 'works_count': 38.0}],
#  '0083-4327': [{'source_id': 4306522935,
#    'fuzzratio': 45.238095238095234,
#    'works_count': 116.0},
#   {'source_id': 4210232959,
#    'fuzzratio': 80.73394495412845,
#    'works_count': 116.0}],
#  '0084-3717': [{'source_id': 4210225280,
#    'fuzzratio': 98.11320754716981,
#    'works_count': 0.0},
#   {'source_id': 136007311, 'fuzzratio': 87.5, 'works_count': 554.0}],
#  '0084-3741': [{'source_id': 4210213380,
#    'fuzzratio': 98.36065573770492,
#    'works_count': 0.0},
#   {'source_id': 65098588,
#    'fuzzratio': 89.28571428571429,
#    'works_count': 1440.0}],
#  '0084-9537': [{'source_id': 4306507506,
#    'fuzzratio': 100.0,
#    'works_count': 297.0},
#   {'source_id': 4210215507, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0085-2376': [{'source_id': 187415269,
#    'fuzzratio': 100.0,
#    'works_count': 1004.0},
#   {'source_id': 4210182348, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0090-8290': [{'source_id': 134101889,
#    'fuzzratio': 100.0,
#    'works_count': 12.0},
#   {'source_id': 4210229292, 'fuzzratio': 100.0, 'works_count': 4548.0}],
#  '0091-1801': [{'source_id': 4210222833,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 2764947516, 'fuzzratio': 100.0, 'works_count': 698.0}],
#  '0093-3619': [{'source_id': 30421737,
#    'fuzzratio': 59.74025974025974,
#    'works_count': 2332.0},
#   {'source_id': 4210213382,
#    'fuzzratio': 98.24561403508771,
#    'works_count': 1.0}],
#  '0094-002X': [{'source_id': 4306501588,
#    'fuzzratio': 100.0,
#    'works_count': 246.0},
#   {'source_id': 4210179730, 'fuzzratio': 100.0, 'works_count': 501.0}],
#  '0094-243X': [{'source_id': 4306501195,
#    'fuzzratio': 100.0,
#    'works_count': 5144.0},
#   {'source_id': 2764696622, 'fuzzratio': 100.0, 'works_count': 241059.0}],
#  '0094-8594': [{'source_id': 2764569203,
#    'fuzzratio': 100.0,
#    'works_count': 4.0},
#   {'source_id': 4210240008, 'fuzzratio': 100.0, 'works_count': 544.0}],
#  '0095-0033': [{'source_id': 4210168346,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 199280970,
#    'fuzzratio': 57.14285714285714,
#    'works_count': 1245.0}],
#  '0095-2737': [{'source_id': 202349295,
#    'fuzzratio': 65.75342465753424,
#    'works_count': 4.0},
#   {'source_id': 4210183329,
#    'fuzzratio': 63.33333333333333,
#    'works_count': 1044.0}],
#  '0095-8751': [{'source_id': 2764735499,
#    'fuzzratio': 71.7948717948718,
#    'works_count': 2.0},
#   {'source_id': 4210169394, 'fuzzratio': 100.0, 'works_count': 1390.0}],
#  '0095-9006': [{'source_id': 4210206097,
#    'fuzzratio': 100.0,
#    'works_count': 414.0},
#   {'source_id': 2764522905, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0095-9073': [{'source_id': 4210184266,
#    'fuzzratio': 100.0,
#    'works_count': 581.0},
#   {'source_id': 2764736219, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0096-039X': [{'source_id': 2755505197,
#    'fuzzratio': 100.0,
#    'works_count': 794.0},
#   {'source_id': 4210210014,
#    'fuzzratio': 96.42857142857143,
#    'works_count': 0.0}],
#  '0096-1639': [{'source_id': 128239818,
#    'fuzzratio': 65.24064171122994,
#    'works_count': 2.0},
#   {'source_id': 4210219929,
#    'fuzzratio': 65.24064171122994,
#    'works_count': 438.0}],
#  '0096-1655': [{'source_id': 4210173205,
#    'fuzzratio': 100.0,
#    'works_count': 331.0},
#   {'source_id': 169231173, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0096-1663': [{'source_id': 56565619,
#    'fuzzratio': 100.0,
#    'works_count': 128.0},
#   {'source_id': 4210204605, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0096-1760': [{'source_id': 4210205767,
#    'fuzzratio': 97.2972972972973,
#    'works_count': 0.0},
#   {'source_id': 132147440,
#    'fuzzratio': 97.2972972972973,
#    'works_count': 68.0}],
#  '0096-1779': [{'source_id': 4210189262,
#    'fuzzratio': 64.56692913385827,
#    'works_count': 0.0},
#   {'source_id': 159982353,
#    'fuzzratio': 64.56692913385827,
#    'works_count': 86.0}],
#  '0096-1884': [{'source_id': 4210217802,
#    'fuzzratio': 64.66165413533835,
#    'works_count': 0.0},
#   {'source_id': 17996268,
#    'fuzzratio': 64.66165413533835,
#    'works_count': 212.0}],
#  '0096-1981': [{'source_id': 36919197,
#    'fuzzratio': 63.29113924050633,
#    'works_count': 500.0},
#   {'source_id': 4210187637,
#    'fuzzratio': 63.29113924050633,
#    'works_count': 0.0}],
#  '0096-199X': [{'source_id': 11838608,
#    'fuzzratio': 64.34782608695653,
#    'works_count': 1.0},
#   {'source_id': 4210168006,
#    'fuzzratio': 64.34782608695653,
#    'works_count': 389.0}],
#  '0096-2015': [{'source_id': 115275344,
#    'fuzzratio': 95.89041095890411,
#    'works_count': 555.0},
#   {'source_id': 4210213319,
#    'fuzzratio': 95.89041095890411,
#    'works_count': 0.0}],
#  '0096-2252': [{'source_id': 154337518,
#    'fuzzratio': 64.61538461538461,
#    'works_count': 2.0},
#   {'source_id': 4210176564,
#    'fuzzratio': 64.61538461538461,
#    'works_count': 336.0}],
#  '0096-2260': [{'source_id': 4210175297,
#    'fuzzratio': 100.0,
#    'works_count': 465.0},
#   {'source_id': 14937319, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0096-2422': [{'source_id': 4210202279,
#    'fuzzratio': 64.22018348623853,
#    'works_count': 164.0},
#   {'source_id': 198002107,
#    'fuzzratio': 64.22018348623853,
#    'works_count': 2.0}],
#  '0096-2430': [{'source_id': 4210178777,
#    'fuzzratio': 96.0,
#    'works_count': 1017.0},
#   {'source_id': 94300131, 'fuzzratio': 96.0, 'works_count': 4.0}],
#  '0096-2511': [{'source_id': 4210214264,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 20422486, 'fuzzratio': 100.0, 'works_count': 376.0}],
#  '0096-252X': [{'source_id': 201202888,
#    'fuzzratio': 64.96815286624205,
#    'works_count': 0.0},
#   {'source_id': 4210219810,
#    'fuzzratio': 64.96815286624205,
#    'works_count': 206.0}],
#  '0096-2805': [{'source_id': 2764844835,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4210185994, 'fuzzratio': 100.0, 'works_count': 199.0}],
#  '0096-2813': [{'source_id': 4210219148,
#    'fuzzratio': 100.0,
#    'works_count': 310.0},
#   {'source_id': 2764572568, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0096-3445': [{'source_id': 4210202991,
#    'fuzzratio': 88.31168831168831,
#    'works_count': 0.0},
#   {'source_id': 62013203, 'fuzzratio': 100.0, 'works_count': 4793.0}],
#  '0097-0298': [{'source_id': 49295888,
#    'fuzzratio': 100.0,
#    'works_count': 82.0},
#   {'source_id': 4210237413, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0097-2460': [{'source_id': 4210198682,
#    'fuzzratio': 77.01863354037268,
#    'works_count': 3053.0},
#   {'source_id': 77999812, 'fuzzratio': 98.0, 'works_count': 3.0}],
#  '0097-4552': [{'source_id': 177429142,
#    'fuzzratio': 100.0,
#    'works_count': 1.0},
#   {'source_id': 4210199867, 'fuzzratio': 100.0, 'works_count': 264.0}],
#  '0097-6156': [{'source_id': 4306500188,
#    'fuzzratio': 100.0,
#    'works_count': 59.0},
#   {'source_id': 205053445, 'fuzzratio': 100.0, 'works_count': 35319.0},
#   {'source_id': 4306500189, 'fuzzratio': 100.0, 'works_count': 78.0}],
#  '0097-6628': [{'source_id': 4210174446,
#    'fuzzratio': 100.0,
#    'works_count': 200.0},
#   {'source_id': 107438032, 'fuzzratio': 100.0, 'works_count': 79.0}],
#  '0097-8043': [{'source_id': 4306525929,
#    'fuzzratio': 100.0,
#    'works_count': 76.0},
#   {'source_id': 4210219680, 'fuzzratio': 100.0, 'works_count': 383.0}],
#  '0098-1672': [{'source_id': 4210188930,
#    'fuzzratio': 98.66666666666667,
#    'works_count': 1450.0},
#   {'source_id': 146788110,
#    'fuzzratio': 91.42857142857143,
#    'works_count': 0.0}],
#  '0098-4582': [{'source_id': 4306506594,
#    'fuzzratio': 100.0,
#    'works_count': 102.0},
#   {'source_id': 4210185562, 'fuzzratio': 100.0, 'works_count': 27.0}],
#  '0099-6866': [{'source_id': 147001222,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4210183094, 'fuzzratio': 100.0, 'works_count': 112.0}],
#  '0099-7056': [{'source_id': 4210227406,
#    'fuzzratio': 100.0,
#    'works_count': 6247.0},
#   {'source_id': 978493527,
#    'fuzzratio': 95.23809523809523,
#    'works_count': 1.0}],
#  '0100-2430': [{'source_id': 68443283,
#    'fuzzratio': 65.60000000000001,
#    'works_count': 558.0},
#   {'source_id': 4306504931,
#    'fuzzratio': 65.04065040650406,
#    'works_count': 448.0}],
#  '0100-2929': [{'source_id': 4306522337,
#    'fuzzratio': 95.0,
#    'works_count': 223.0},
#   {'source_id': 4210233930, 'fuzzratio': 100.0, 'works_count': 105.0}],
#  '0100-3143': [{'source_id': 4306508777,
#    'fuzzratio': 85.0,
#    'works_count': 153.0},
#   {'source_id': 2739092582, 'fuzzratio': 100.0, 'works_count': 1052.0}],
#  '0100-8587': [{'source_id': 2738578083,
#    'fuzzratio': 95.0,
#    'works_count': 507.0},
#   {'source_id': 4210199761, 'fuzzratio': 100.0, 'works_count': 2.0}],
#  '0100-8889': [{'source_id': 4210233459,
#    'fuzzratio': 100.0,
#    'works_count': 18.0},
#   {'source_id': 4210199539, 'fuzzratio': 100.0, 'works_count': 76.0}],
#  '0101-5303': [{'source_id': 4306509972,
#    'fuzzratio': 76.40449438202246,
#    'works_count': 108.0},
#   {'source_id': 4210169866,
#    'fuzzratio': 53.333333333333336,
#    'works_count': 130.0}],
#  '0101-5907': [{'source_id': 5193946,
#    'fuzzratio': 100.0,
#    'works_count': 159.0},
#   {'source_id': 4210197298, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0101-7136': [{'source_id': 4210173309,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 2738165242, 'fuzzratio': 100.0, 'works_count': 828.0}],
#  '0101-7659': [{'source_id': 4306526165,
#    'fuzzratio': 100.0,
#    'works_count': 671.0},
#   {'source_id': 4210221865, 'fuzzratio': 100.0, 'works_count': 205.0}],
#  '0101-8434': [{'source_id': 4210177054,
#    'fuzzratio': 100.0,
#    'works_count': 31.0},
#   {'source_id': 4306527154, 'fuzzratio': 100.0, 'works_count': 2784.0}],
#  '0101-9554': [{'source_id': 4306513530,
#    'fuzzratio': 37.5,
#    'works_count': 178.0},
#   {'source_id': 4210233870, 'fuzzratio': 100.0, 'works_count': 43.0}],
#  '0101-9880': [{'source_id': 60123682,
#    'fuzzratio': 100.0,
#    'works_count': 137.0},
#   {'source_id': 2738612362,
#    'fuzzratio': 98.63013698630137,
#    'works_count': 432.0}],
#  '0102-2482': [{'source_id': 4306527156,
#    'fuzzratio': 80.0,
#    'works_count': 20.0},
#   {'source_id': 4210224305, 'fuzzratio': 100.0, 'works_count': 268.0}],
#  '0102-2717': [{'source_id': 4306520162,
#    'fuzzratio': 37.83783783783784,
#    'works_count': 139.0},
#   {'source_id': 4210176317, 'fuzzratio': 100.0, 'works_count': 367.0}],
#  '0102-2997': [{'source_id': 4306520716,
#    'fuzzratio': 100.0,
#    'works_count': 403.0},
#   {'source_id': 4306520715, 'fuzzratio': 100.0, 'works_count': 80.0}],
#  '0102-3888': [{'source_id': 4210169160,
#    'fuzzratio': 100.0,
#    'works_count': 325.0},
#   {'source_id': 4306511295,
#    'fuzzratio': 64.28571428571428,
#    'works_count': 451.0}],
#  '0102-6003': [{'source_id': 4210224174,
# ...
#    'works_count': 1331.0}],
#  '0916-3786': [{'source_id': 63766127,
#    'fuzzratio': 52.38095238095239,
#    'works_count': 3.0},
#   {'source_id': 4210177817, 'fuzzratio': 100.0, 'works_count': 434.0}],
#  '0916-5835': [{'source_id': 118453086,
#    'fuzzratio': 35.051546391752574,
#    'works_count': 268.0},
#   {'source_id': 4210228970,
#    'fuzzratio': 64.70588235294117,
#    'works_count': 0.0}],
#  '0916-5908': [{'source_id': 120690400,
#    'fuzzratio': 34.95145631067961,
#    'works_count': 656.0},
#   {'source_id': 4210185010,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 0.0}],
#  '0916-7579': [{'source_id': 4210176692,
#    'fuzzratio': 65.42056074766356,
#    'works_count': 0.0},
#   {'source_id': 93757549,
#    'fuzzratio': 37.383177570093466,
#    'works_count': 117.0}],
#  '0916-8958': [{'source_id': 110317234,
#    'fuzzratio': 29.21348314606742,
#    'works_count': 1934.0},
#   {'source_id': 4210221864,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 0.0}],
#  '0918-0729': [{'source_id': 4210168231,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 1191.0},
#   {'source_id': 60077732, 'fuzzratio': 60.40268456375839, 'works_count': 7.0}],
#  '0918-1067': [{'source_id': 111359038,
#    'fuzzratio': 28.125,
#    'works_count': 77.0},
#   {'source_id': 4210194237, 'fuzzratio': 100.0, 'works_count': 333.0}],
#  '0918-4430': [{'source_id': 4210233217,
#    'fuzzratio': 74.07407407407408,
#    'works_count': 514.0},
#   {'source_id': 2764356019,
#    'fuzzratio': 74.07407407407408,
#    'works_count': 1.0}],
#  '0918-6638': [{'source_id': 4210227123,
#    'fuzzratio': 64.1025641025641,
#    'works_count': 0.0},
#   {'source_id': 154852912,
#    'fuzzratio': 64.1025641025641,
#    'works_count': 354.0}],
#  '0919-0945': [{'source_id': 125174104,
#    'fuzzratio': 39.02439024390244,
#    'works_count': 11849.0},
#   {'source_id': 4210237177,
#    'fuzzratio': 64.64646464646464,
#    'works_count': 0.0}],
#  '0920-055X': [{'source_id': 4210230722,
#    'fuzzratio': 100.0,
#    'works_count': 389.0},
#   {'source_id': 4306525631, 'fuzzratio': 100.0, 'works_count': 329.0}],
#  '0920-8100': [{'source_id': 4210214824,
#    'fuzzratio': 65.06024096385542,
#    'works_count': 1129.0},
#   {'source_id': 105773129,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 43.0}],
#  '0921-254X': [{'source_id': 127352628,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4210213880, 'fuzzratio': 100.0, 'works_count': 151.0}],
#  '0921-2647': [{'source_id': 50861661, 'fuzzratio': 100.0, 'works_count': 0.0},
#   {'source_id': 4210184105, 'fuzzratio': 100.0, 'works_count': 480.0}],
#  '0924-6304': [{'source_id': 4210194238,
#    'fuzzratio': 100.0,
#    'works_count': 7136.0},
#   {'source_id': 4306518990,
#    'fuzzratio': 12.244897959183676,
#    'works_count': 160.0}],
#  '0924-7025': [{'source_id': 4306530886,
#    'fuzzratio': 100.0,
#    'works_count': 259.0},
#   {'source_id': 4210189413, 'fuzzratio': 100.0, 'works_count': 59.0}],
#  '0925-8604': [{'source_id': 4306520695,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 363.0},
#   {'source_id': 4306520694,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 79.0}],
#  '0925-9643': [{'source_id': 4210222580,
#    'fuzzratio': 100.0,
#    'works_count': 53.0},
#   {'source_id': 4306534102, 'fuzzratio': 100.0, 'works_count': 730.0}],
#  '0927-5193': [{'source_id': 4210169129,
#    'fuzzratio': 70.37037037037037,
#    'works_count': 0.0},
#   {'source_id': 170438645,
#    'fuzzratio': 61.386138613861384,
#    'works_count': 1683.0}],
#  '0929-077X': [{'source_id': 120970199,
#    'fuzzratio': 100.0,
#    'works_count': 7.0},
#   {'source_id': 4210226040, 'fuzzratio': 100.0, 'works_count': 527.0}],
#  '0929-8622': [{'source_id': 87527080,
#    'fuzzratio': 100.0,
#    'works_count': 50.0},
#   {'source_id': 4210172637, 'fuzzratio': 100.0, 'works_count': 318.0}],
#  '0932-0776': [{'source_id': 104732370,
#    'fuzzratio': 65.97938144329896,
#    'works_count': 19536.0},
#   {'source_id': 4306535541,
#    'fuzzratio': 63.26530612244898,
#    'works_count': 301.0}],
#  '0933-3053': [{'source_id': 4210212082,
#    'fuzzratio': 100.0,
#    'works_count': 76.0},
#   {'source_id': 113003143, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0939-8368': [{'source_id': 4210175449,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 40402612, 'fuzzratio': 100.0, 'works_count': 707.0}],
#  '0940-5569': [{'source_id': 4210205478,
#    'fuzzratio': 96.2962962962963,
#    'works_count': 0.0},
#   {'source_id': 4306535619, 'fuzzratio': 100.0, 'works_count': 316.0}],
#  '0942-1017': [{'source_id': 4210231369,
#    'fuzzratio': 85.71428571428572,
#    'works_count': 218.0},
#   {'source_id': 4306524536,
#    'fuzzratio': 79.06976744186046,
#    'works_count': 237.0}],
#  '0943-3481': [{'source_id': 167767754,
#    'fuzzratio': 91.66666666666666,
#    'works_count': 2.0},
#   {'source_id': 4210225946, 'fuzzratio': 100.0, 'works_count': 453.0}],
#  '0943-4011': [{'source_id': 4210187776,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 743.0},
#   {'source_id': 4306515256,
#    'fuzzratio': 62.33766233766234,
#    'works_count': 45.0}],
#  '0944-1166': [{'source_id': 48036798, 'fuzzratio': 100.0, 'works_count': 5.0},
#   {'source_id': 4210215194, 'fuzzratio': 100.0, 'works_count': 1503.0}],
#  '0947-8094': [{'source_id': 4306517442,
#    'fuzzratio': 68.08510638297872,
#    'works_count': 70.0},
#   {'source_id': 4210209691,
#    'fuzzratio': 62.22222222222222,
#    'works_count': 123.0}],
#  '0949-2488': [{'source_id': 47516336, 'fuzzratio': 100.0, 'works_count': 0.0},
#   {'source_id': 4210172144, 'fuzzratio': 100.0, 'works_count': 792.0}],
#  '0950-5636': [{'source_id': 4210180802,
#    'fuzzratio': 100.0,
#    'works_count': 212.0},
#   {'source_id': 6101083, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0952-9608': [{'source_id': 4210176481,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 83219165, 'fuzzratio': 37.5, 'works_count': 156.0}],
#  '0953-9964': [{'source_id': 63670058, 'fuzzratio': 100.0, 'works_count': 0.0},
#   {'source_id': 4210186426, 'fuzzratio': 100.0, 'works_count': 498.0}],
#  '0954-0091': [{'source_id': 4210188800,
#    'fuzzratio': 100.0,
#    'works_count': 1038.0},
#   {'source_id': 159543560, 'fuzzratio': 100.0, 'works_count': 75.0}],
#  '0954-0350': [{'source_id': 113784129,
#    'fuzzratio': 96.42857142857143,
#    'works_count': 0.0},
#   {'source_id': 4210225753, 'fuzzratio': 100.0, 'works_count': 26.0}],
#  '0956-3385': [{'source_id': 36916053,
#    'fuzzratio': 100.0,
#    'works_count': 117.0},
#   {'source_id': 4210171075, 'fuzzratio': 95.0, 'works_count': 1309.0}],
#  '0957-042X': [{'source_id': 51949540, 'fuzzratio': 100.0, 'works_count': 0.0},
#   {'source_id': 4210168495, 'fuzzratio': 100.0, 'works_count': 293.0}],
#  '0957-7742': [{'source_id': 2754977200,
#    'fuzzratio': 76.47058823529412,
#    'works_count': 354.0},
#   {'source_id': 2765017660,
#    'fuzzratio': 45.16129032258065,
#    'works_count': 1.0}],
#  '0957-798X': [{'source_id': 4210208990,
#    'fuzzratio': 100.0,
#    'works_count': 1153.0},
#   {'source_id': 2764709026, 'fuzzratio': 100.0, 'works_count': 7.0}],
#  '0959-3527': [{'source_id': 4210170136,
#    'fuzzratio': 100.0,
#    'works_count': 121.0},
#   {'source_id': 99341716, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0959-4213': [{'source_id': 4210183013,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 57158648, 'fuzzratio': 100.0, 'works_count': 422.0}],
#  '0959-9304': [{'source_id': 4210217007,
#    'fuzzratio': 93.33333333333333,
#    'works_count': 0.0},
#   {'source_id': 2765057155, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0961-088X': [{'source_id': 61068122,
#    'fuzzratio': 100.0,
#    'works_count': 44.0},
#   {'source_id': 4210220233, 'fuzzratio': 100.0, 'works_count': 3.0}],
#  '0962-2519': [{'source_id': 107336951,
#    'fuzzratio': 87.87878787878788,
#    'works_count': 374.0},
#   {'source_id': 4210221944,
#    'fuzzratio': 27.906976744186053,
#    'works_count': 0.0}],
#  '0962-7375': [{'source_id': 4210185567,
#    'fuzzratio': 100.0,
#    'works_count': 366.0},
#   {'source_id': 2764726901,
#    'fuzzratio': 83.6734693877551,
#    'works_count': 0.0}],
#  '0964-2749': [{'source_id': 4210228343,
#    'fuzzratio': 100.0,
#    'works_count': 740.0},
#   {'source_id': 2764769230, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0966-1905': [{'source_id': 4210217177,
#    'fuzzratio': 100.0,
#    'works_count': 1120.0},
#   {'source_id': 2764892950, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0968-0454': [{'source_id': 101733996,
#    'fuzzratio': 69.0909090909091,
#    'works_count': 11.0},
#   {'source_id': 4210199606,
#    'fuzzratio': 52.05479452054795,
#    'works_count': 6.0}],
#  '0968-0470': [{'source_id': 165960630,
#    'fuzzratio': 69.23076923076923,
#    'works_count': 37.0},
#   {'source_id': 4210196061,
#    'fuzzratio': 54.28571428571429,
#    'works_count': 18.0}],
#  '0968-4891': [{'source_id': 4210224981,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 186061455, 'fuzzratio': 100.0, 'works_count': 112.0}],
#  '0968-4905': [{'source_id': 52066020,
#    'fuzzratio': 67.44186046511628,
#    'works_count': 0.0},
#   {'source_id': 4210190444,
#    'fuzzratio': 64.28571428571428,
#    'works_count': 17.0}],
#  '0968-9427': [{'source_id': 170317308,
#    'fuzzratio': 100.0,
#    'works_count': 1.0},
#   {'source_id': 4210222583, 'fuzzratio': 100.0, 'works_count': 258.0}],
#  '0970-1052': [{'source_id': 4210185777,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 307.0},
#   {'source_id': 4306518637,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 120.0}],
#  '0970-5333': [{'source_id': 2764510218,
#    'fuzzratio': 100.0,
#    'works_count': 9.0},
#   {'source_id': 4210188869,
#    'fuzzratio': 83.01886792452831,
#    'works_count': 469.0}],
#  '0971-0701': [{'source_id': 4210237438,
#    'fuzzratio': 100.0,
#    'works_count': 432.0},
#   {'source_id': 4210178253, 'fuzzratio': 100.0, 'works_count': 0.0},
#   {'source_id': 4210238055, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0971-4251': [{'source_id': 2764916325,
#    'fuzzratio': 66.07142857142857,
#    'works_count': 303.0},
#   {'source_id': 4210174936,
#    'fuzzratio': 68.96551724137932,
#    'works_count': 0.0}],
#  '0971-6378': [{'source_id': 2765025767,
#    'fuzzratio': 71.42857142857143,
#    'works_count': 9.0},
#   {'source_id': 4306536274,
#    'fuzzratio': 64.70588235294117,
#    'works_count': 463.0}],
#  '0971-9903': [{'source_id': 2764472474,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 0.0},
#   {'source_id': 4210233429,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 352.0}],
#  '0972-0510': [{'source_id': 2764706862,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 1646.0},
#   {'source_id': 4210170916,
#    'fuzzratio': 66.14173228346456,
#    'works_count': 0.0}],
#  '0972-0820': [{'source_id': 4210173563,
#    'fuzzratio': 100.0,
#    'works_count': 740.0},
#   {'source_id': 2765013190, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0972-1282': [{'source_id': 4210198165,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 2765075872, 'fuzzratio': 100.0, 'works_count': 270.0}],
#  '0972-7671': [{'source_id': 4387277859,
#    'fuzzratio': 24.561403508771928,
#    'works_count': 102.0},
#   {'source_id': 42417332, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0972-8864': [{'source_id': 4210179805,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 22436737, 'fuzzratio': 100.0, 'works_count': 15.0}],
#  '0972-9968': [{'source_id': 4210193845,
#    'fuzzratio': 100.0,
#    'works_count': 73.0},
#   {'source_id': 4210222683, 'fuzzratio': 100.0, 'works_count': 76.0}],
#  '0973-0354': [{'source_id': 4210206982,
#    'fuzzratio': 65.85365853658536,
#    'works_count': 0.0},
#   {'source_id': 2764746808,
#    'fuzzratio': 66.66666666666667,
#    'works_count': 479.0}],
#  '0973-1873': [{'source_id': 204095610,
#    'fuzzratio': 66.29834254143645,
#    'works_count': 184.0},
#   {'source_id': 4210222161,
#    'fuzzratio': 66.29834254143645,
#    'works_count': 0.0}],
#  '0973-2209': [{'source_id': 4393920010,
#    'fuzzratio': 100.0,
#    'works_count': 133.0},
#   {'source_id': 4210201600,
#    'fuzzratio': 66.24203821656052,
#    'works_count': 284.0}],
#  '0973-2543': [{'source_id': 4306536274,
#    'fuzzratio': 64.70588235294117,
#    'works_count': 463.0},
#   {'source_id': 2765025767,
#    'fuzzratio': 71.42857142857143,
#    'works_count': 9.0}],
#  '0973-3469': [{'source_id': 4210192902,
#    'fuzzratio': 65.95744680851064,
#    'works_count': 771.0},
#   {'source_id': 2764978433,
#    'fuzzratio': 65.95744680851064,
#    'works_count': 0.0}],
#  '0973-9084': [{'source_id': 4210238897,
#    'fuzzratio': 100.0,
#    'works_count': 142.0},
#   {'source_id': 2764491566,
#    'fuzzratio': 98.94736842105263,
#    'works_count': 0.0}],
#  '0973-9157': [{'source_id': 2765020732,
#    'fuzzratio': 98.18181818181819,
#    'works_count': 0.0},
#   {'source_id': 4210173669, 'fuzzratio': 100.0, 'works_count': 322.0}],
#  '0974-0171': [{'source_id': 2764916325,
#    'fuzzratio': 66.07142857142857,
#    'works_count': 303.0},
#   {'source_id': 4210174936,
#    'fuzzratio': 68.96551724137932,
#    'works_count': 0.0}],
#  '0974-1216': [{'source_id': 98551714, 'fuzzratio': 100.0, 'works_count': 1.0},
#   {'source_id': 4210189098, 'fuzzratio': 100.0, 'works_count': 50.0}],
#  '0974-1259': [{'source_id': 4210222161,
#    'fuzzratio': 66.29834254143645,
#    'works_count': 0.0},
#   {'source_id': 204095610,
#    'fuzzratio': 66.29834254143645,
#    'works_count': 184.0}],
#  '0974-150X': [{'source_id': 4210237627,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 4210185568, 'fuzzratio': 100.0, 'works_count': 812.0}],
#  '0974-5041': [{'source_id': 2764753543,
#    'fuzzratio': 90.9090909090909,
#    'works_count': 16.0},
#   {'source_id': 4210226735, 'fuzzratio': 100.0, 'works_count': 394.0}],
#  '0974-5904': [{'source_id': 4210193696,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 2764965852, 'fuzzratio': 100.0, 'works_count': 165.0}],
#  '0974-7818': [{'source_id': 4210189098,
#    'fuzzratio': 100.0,
#    'works_count': 50.0},
#   {'source_id': 98551714, 'fuzzratio': 100.0, 'works_count': 1.0}],
#  '0974-8938': [{'source_id': 4210192119,
#    'fuzzratio': 40.50632911392405,
#    'works_count': 0.0},
#   {'source_id': 2765001677,
#    'fuzzratio': 40.50632911392405,
#    'works_count': 1464.0}],
#  '0974-9632': [{'source_id': 2765076910,
#    'fuzzratio': 47.05882352941176,
#    'works_count': 432.0},
#   {'source_id': 4393916453, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0975-0282': [{'source_id': 991499945,
#    'fuzzratio': 100.0,
#    'works_count': 42.0},
#   {'source_id': 4210211723,
#    'fuzzratio': 90.09009009009009,
#    'works_count': 382.0}],
#  '0975-0290': [{'source_id': 991499945,
#    'fuzzratio': 100.0,
#    'works_count': 42.0},
#   {'source_id': 4210211723,
#    'fuzzratio': 90.09009009009009,
#    'works_count': 382.0}],
#  '0975-1920': [{'source_id': 4210192119,
#    'fuzzratio': 40.50632911392405,
#    'works_count': 0.0},
#   {'source_id': 2765001677,
#    'fuzzratio': 40.50632911392405,
#    'works_count': 1464.0}],
#  '0975-251X': [{'source_id': 4210205304,
#    'fuzzratio': 65.85365853658536,
#    'works_count': 33.0},
#   {'source_id': 4210187207, 'fuzzratio': 100.0, 'works_count': 12.0}],
#  '0975-2625': [{'source_id': 2764812143,
#    'fuzzratio': 92.5925925925926,
#    'works_count': 834.0},
#   {'source_id': 4210223935, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0975-3605': [{'source_id': 2764540303,
#    'fuzzratio': 100.0,
#    'works_count': 660.0},
#   {'source_id': 4210191971, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0975-5276': [{'source_id': 4210179426,
#    'fuzzratio': 100.0,
#    'works_count': 205.0},
#   {'source_id': 2765055540, 'fuzzratio': 100.0, 'works_count': 5.0}],
#  '0975-5586': [{'source_id': 181807688,
#    'fuzzratio': 100.0,
#    'works_count': 201.0},
#   {'source_id': 4210194872, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0975-5705': [{'source_id': 150306837,
#    'fuzzratio': 100.0,
#    'works_count': 317.0},
#   {'source_id': 4210179336, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  '0975-5926': [{'source_id': 4210194872,
#    'fuzzratio': 100.0,
#    'works_count': 0.0},
#   {'source_id': 181807688, 'fuzzratio': 100.0, 'works_count': 201.0}],
#  '0975-5985': [{'source_id': 150306837,
#    'fuzzratio': 100.0,
#    'works_count': 317.0},
#   {'source_id': 4210179336, 'fuzzratio': 100.0, 'works_count': 0.0}],
#  ...}

# %%
x = pd.DataFrame(num_sources_verify)
x[x['num_sources_db']!=x['num_sources_in_openalex']]
# Out:
#            issn  num_sources_in_openalex  num_sources_db
# 828   0794-5698                        2               1
# 829   0794-9316                        2               1
# 1190  1099-0046                        2               1
# 1970  1443-458X                        2               1
# 2063  1522-9580                        2               1
# 2082  1529-1529                        2               1
# 3013  1826-9850                        2               3
# 3475  1936-9956                        2               1
# 4341  2091-0762                        2               1
# 6028  2356-9816                        2               1
# 6357  2410-7980                        2               1
# 6669  2472-7121                        2               1
# 6670  2472-7164                        2               1

# %%
issnldups = df_midjournal.dropna(subset='issn')
issnldups = issnldups[issnldups['issn'].duplicated(keep=False)]
print(len(issnldups))
print(issnldups['issn'].nunique())
print(issnldups['journal_id'].nunique())
# Out:
# 8430
# 4170
# 8430

# %%
#go through each of these above (groupby issn, which should be the issnl), and dedup. delete any which aren't issnls (maybe check them for data later).
#add missing sources from data file (any issnl that doesn't have a source_id identified by issnl)
#this should leave us with no duplicate issns
#then figure out how to resolve any issns that resolve to multiple

# %%
# %%time
try:
    num_updated = 0
    n_issn = issnldups['issn'].nunique()
    no_dd_found = []
    for issn, gbdf in tqdm(issnldups.set_index('journal_id', verify_integrity=True).groupby('issn'), total=n_issn):
        now = datetime.now(timezone.utc).isoformat()
        try:
            dd = dups_data[issn]
        except KeyError:
            no_dd_found.append(issn)
            continue
        if len(dd) != 2:
            # come back to these
            continue
        dd.sort(key=lambda x: x['works_count'], reverse=True)
        conditions = [
            dd[0]['works_count'] >= dd[1]['works_count'],
            dd[0]['fuzzratio'] >= 95,
        ]
        if all(conditions):
            # all conditions met. merge second source into first
            id_to_merge = dd[1]['source_id']
            merge_into_id = dd[0]['source_id']
            source = db.session.query(Source).filter_by(journal_id=id_to_merge).one()
            source.merge_into_id = merge_into_id
            source.merge_into_date = now
            source.updated_date = now

            db.session.add(source)

            note = f"merged because lower works count."
            row = gbdf.loc[id_to_merge].fillna(value=0)
            if row['publisher_id'] or row['alternate_titles']:
                note += " may have additional info."

            sq = """INSERT INTO issn_audit_20240321.update5
                    (source_id, updated_date, merge_into_id, note)
                    VALUES(:source_id, :now, :merge_into_id, :note);"""
            db.session.execute(text(sq), {
                'source_id': source.id,
                'now': now,
                'merge_into_id': merge_into_id,
                'note': note,
            })

            sq = """update issn_audit_20240321.issn_ic_datafile_202402 set resolved = true
                where "submitted_1348-0278" = :issn"""
            db.session.execute(text(sq), {
                'issn': issn,
            })

            num_updated += 1
    db.session.commit()
    print(f"{num_updated} updated")
finally:
    db.session.close
# Out:
# 100%|██████████| 4170/4170 [22:34<00:00,  3.08it/s]
# 2337 updated
# CPU times: user 44.7 s, sys: 1.62 s, total: 46.3 s
# Wall time: 23min 20s

# %%
dd
# Out:
# [{'source_id': 4306504665, 'fuzzratio': 100.0, 'works_count': 326.0},
#  {'source_id': 4306504666, 'fuzzratio': 100.0, 'works_count': 84.0}]

# %%
row
# Out:
#                                  display_name       issn          issns
# journal_id
# 4306504665  Boletín de la Academia colombiana  0001-3773  ["0001-3773"]  \
# 4306504666  Boletín de la Academia Colombiana  0001-3773  ["0001-3773"]
#
#            issns_text_array     type country_code alternate_titles
# journal_id
# 4306504665      [0001-3773]  journal         None               []  \
# 4306504666      [0001-3773]  journal         None               []
#
#             publisher_id  works_count
# journal_id
# 4306504665           NaN        326.0
# 4306504666           NaN         84.0

# %%
if row['publisher_id'].fillna(value=0).iloc[0]:
    print('d')

# %%
row.iloc[0]['alternate_titles']
# Out:
# []

# %%
import pickle
outfp = Path('../data/issn_audit_20240301/dups_data.pickle')
outfp.write_bytes(pickle.dumps(dups_data))
# Out:
# 893665
