# %% [markdown]
# # update4 post-mortem
#
# * mid.journal.issns and mid.journal.issns_text_array should have identical information
# * every ISSNL in mid.journal.issn should be the first item in the lists mid.journal.issns, and mid.journal.issns_text_array
# * there should be no duplicate ISSNL (no duplicate mid.journal.issn)
# * every ISSN should resolve to one Source (only one entry in mid.journal has the ISSN in issns/issns_text_array)

# %%
import sys

# %%
sys.path.append('../..')

# %%
from datetime import datetime, timezone
import json
from tqdm import tqdm
from pathlib import Path
import gzip

# %%
import pandas as pd
import numpy as np

# %%
import rapidfuzz

# %%
from app import db
from models import Source, ISSNtoISSNL
from sqlalchemy import text
from sqlalchemy.orm import Load
from sqlalchemy.exc import MultipleResultsFound
# Out:
# 139712131965312: loading merged_into_institutions_dict
# 139712131965312: loading valid concept IDs
# 139712131965312: loading valid topic IDs

# %%
# %%time
df_issnl_file = pd.read_sql_query('select * from issn_audit_20240321.issn_ic_datafile_expanded_202402', db.engine)
# Out:
# CPU times: user 1.34 s, sys: 185 ms, total: 1.53 s
# Wall time: 2.61 s

# %%
# %%time
sq = """select journal_id, display_name, issn, issns, issns_text_array, type, country_code, alternate_titles, publisher_id
    from mid.journal
    where merge_into_id is null"""
df_midjournal = pd.read_sql_query(sq, db.engine)
# Out:
# CPU times: user 1.95 s, sys: 33.5 ms, total: 1.99 s
# Wall time: 2.44 s

# %%
print(len(df_midjournal))
df_midjournal.dropna(subset='issn', inplace=True)
print(len(df_midjournal))
# Out:
# 261661
# 148415

# %%
# %%time
sq = """select journal_id, paper_count, citation_count from mid.citation_journals_mv;"""
df_source_counts = pd.read_sql_query(sq, db.engine)
# Out:
# CPU times: user 300 ms, sys: 0 ns, total: 300 ms
# Wall time: 563 ms

# %%
df_midjournal = df_midjournal.merge(df_source_counts, how='left', on='journal_id')

# %%
df_midjournal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148415 entries, 0 to 148414
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   journal_id        148415 non-null  int64
#  1   display_name      148415 non-null  object
#  2   issn              148415 non-null  object
#  3   issns             148415 non-null  object
#  4   issns_text_array  148415 non-null  object
#  5   type              148290 non-null  object
#  6   country_code      109641 non-null  object
#  7   alternate_titles  118625 non-null  object
#  8   publisher_id      67149 non-null   float64
#  9   paper_count       116515 non-null  float64
#  10  citation_count    116515 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 12.5+ MB

# %% [markdown]
# ### mid.journal.issns and mid.journal.issns_text_array should have identical information

# %%
s1 = df_midjournal['issns'].apply(json.loads)
s2 = df_midjournal['issns_text_array']
(s1 == s2).value_counts()
# Out:
# True    148415
# Name: count, dtype: int64

# %% [markdown]
# We're good!

# %% [markdown]
# ### every ISSNL in mid.journal.issn should appear in the lists mid.journal.issns, and mid.journal.issns_text_array

# %%
x = df_midjournal.apply(lambda row: row['issn'] == row['issns_text_array'][0], axis=1)
x.value_counts()
# Out:
# True     146815
# False      1600
# Name: count, dtype: int64

# %%
df_midjournal[x==False]
# Out:
#         journal_id                                       display_name
# 257     4210197708                            Energy research letters  \
# 1016    4210231708                                               eBMJ
# 1136    4210201839                  Intrinsically disordered proteins
# 1206    4210191895      Polilingvialʹnostʹ i transkulʹturnye praktiki
# 1449     155963401                            Nations and nationalism
# ...            ...                                                ...
# 260070  2764864708                  Sudan journal of medical sciences
# 260754  4210209763  Revista respaldo : educación, tecnología y des...
# 260982  4210192115                 Ecología austral/Ecología austral
# 261107   989140491                   Klinik psikofarmakoloji bülteni
# 261542  2764783660             Focus on health professional education
#
#              issn                                    issns
# 257     2652-6433               ["2652-6514", "2652-6433"]  \
# 1016    1468-5833               ["0267-0623", "1468-5833"]
# 1136    2169-0707               ["2169-0693", "2169-0707"]
# 1206    2618-897X                ["2618-8988","2618-897X"]
# 1449    1354-5078  ["1345-5078", "1469-8129", "1354-5078"]
# ...           ...                                      ...
# 260070  1858-5051               ["1858-8530", "1858-5051"]
# 260754  1659-3464  ["2215-4345", "1659-3464", "2215-4337"]
# 260982  0327-5477  ["1667-7838", "0327-5477", "1667-782X"]
# 261107  1302-9657               ["1017-7833", "1302-9657"]
# 261542  2204-7662               ["1442-1100", "2204-7662"]
#
#                          issns_text_array     type country_code
# 257                [2652-6514, 2652-6433]  journal           AU  \
# 1016               [0267-0623, 1468-5833]  journal           GB
# 1136               [2169-0693, 2169-0707]  journal           US
# 1206               [2618-8988, 2618-897X]  journal           RU
# 1449    [1345-5078, 1469-8129, 1354-5078]  journal           GB
# ...                                   ...      ...          ...
# 260070             [1858-8530, 1858-5051]  journal           SD
# 260754  [2215-4345, 1659-3464, 2215-4337]  journal           CR
# 260982  [1667-7838, 0327-5477, 1667-782X]  journal           AR
# 261107             [1017-7833, 1302-9657]  journal           TR
# 261542             [1442-1100, 2204-7662]  journal           AU
#
#                                     alternate_titles  publisher_id
# 257                                               []           NaN
# 1016             [eBritish medical journal (London)]  4.310320e+09
# 1136            [IDP, Intrinsically Disord Proteins]  4.310321e+09
# 1206    [Polylinguality and transcultural practices]  4.310313e+09
# 1449                                              []  4.310321e+09
# ...                                              ...           ...
# 260070                                            []  4.310319e+09
# 260754                                            []  4.310319e+09
# 260982                                            []           NaN
# 261107     [Bulletin of clinical psychopharmacology]  4.310321e+09
# 261542                                            []  4.310314e+09
#
# [1600 rows x 9 columns]

# %%
df_issnl_file['issns'].duplicated().sum()
# Out:
# 0

# %%
invalid = df_issnl_file[df_issnl_file['valid_issns'].isna()]

# %%
invalid
# Out:
#             issns  original_line_number valid_issns issnl
# 646     0855-1448                   636        None  None  \
# 1486    2091-0916                  1466        None  None
# 2003    0794-4721                  1978        None  None
# 2914    1936-9956                  2878        None  None
# 2979    2091-1459                  2943        None  None
# ...           ...                   ...         ...   ...
# 215072  7519-1735                215073        None  None
# 215081  8941-1991                215082        None  None
# 215082  9999-9870                215083        None  None
# 215083  9999-9997                215084        None  None
# 215084  9999-9998                215085        None  None
#
#                                               diagnostics cluster_title
# 646                          0855-1448: ISSN category fre          None  \
# 1486                         2091-0916: ISSN category fre          None
# 2003                         0794-4721: ISSN category val          None
# 2914                         1936-9956: ISSN category val          None
# 2979                         2091-1459: ISSN category val          None
# ...                                                   ...           ...
# 215072  7519-1735: Unknown or invalid ISSN code 7519-1735          None
# 215081  8941-1991: Unknown or invalid ISSN code 8941-1991          None
# 215082  9999-9870: Unknown or invalid ISSN code 9999-9870          None
# 215083  9999-9997: Unknown or invalid ISSN code 9999-9997          None
# 215084  9999-9998: Unknown or invalid ISSN code 9999-9998          None
#
#        print_issn print_category print_medium print_frequency  ...
# 646          None           None         None            None  ...  \
# 1486         None           None         None            None  ...
# 2003         None           None         None            None  ...
# 2914         None           None         None            None  ...
# 2979         None           None         None            None  ...
# ...           ...            ...          ...             ...  ...
# 215072       None           None         None            None  ...
# 215081       None           None         None            None  ...
# 215082       None           None         None            None  ...
# 215083       None           None         None            None  ...
# 215084       None           None         None            None  ...
#
#        disk_category disk_medium disk_frequency disk_country disk_center
# 646             None        None           None         None        None  \
# 1486            None        None           None         None        None
# 2003            None        None           None         None        None
# 2914            None        None           None         None        None
# 2979            None        None           None         None        None
# ...              ...         ...            ...          ...         ...
# 215072          None        None           None         None        None
# 215081          None        None           None         None        None
# 215082          None        None           None         None        None
# 215083          None        None           None         None        None
# 215084          None        None           None         None        None
#
#        disk_language disk_start disk_end disk_title disk_comment
# 646             None       None     None       None         None
# 1486            None       None     None       None         None
# 2003            None       None     None       None         None
# 2914            None       None     None       None         None
# 2979            None       None     None       None         None
# ...              ...        ...      ...        ...          ...
# 215072          None       None     None       None         None
# 215081          None       None     None       None         None
# 215082          None       None     None       None         None
# 215083          None       None     None       None         None
# 215084          None       None     None       None         None
#
# [1518 rows x 39 columns]

# %%
df_midjournal['issn'].duplicated().sum()
# Out:
# 4260

# %%
# %%time
sq = """select journal_id, paper_count, citation_count from mid.citation_journals_mv;"""
df_source_counts = pd.read_sql_query(sq, db.engine)
# Out:
# CPU times: user 282 ms, sys: 17.7 ms, total: 300 ms
# Wall time: 886 ms

# %%
df_midjournal = df_midjournal.merge(df_source_counts, how='left', on='journal_id')

# %%
df_midjournal['paper_count'].isna().sum()
# Out:
# 31900

# %% [markdown]
# ### all issn-ls must resolve to one source

# %%
df_issnl_dups = df_midjournal[df_midjournal['issn'].duplicated(keep=False)]
print(len(df_issnl_dups))
# Out:
# 8430

# %%
df_issnl_dups
# Out:
#         journal_id                                       display_name
# 432     2754219712          Acta obstetrica et gynaecologica Japonica  \
# 773     4210205244                   Perspectivas en nutricion humana
# 775     4210211489  Jurnal Akuntansi Kontemporer: kajian ilmu akun...
# 864     4210234779                      Diabetologia Notes de lecture
# 1147    4210191895      Polilingvialʹnostʹ i transkulʹturnye praktiki
# ...            ...                                                ...
# 143577  4210178777               IRE transactions on electron devices
# 144381  4210204203  Bulletin international des sociétés de secours...
# 145906  4210203785                   Arts and social sciences journal
# 147179  3035235436   Journal of Modern Power Systems and Clean Energy
# 147516    73987262                                ACM Sigois Bulletin
#
#              issn                       issns     type country_code
# 432     0001-6330               ["0001-6330"]  journal           JP  \
# 773     0124-4108   ["0124-4108","2248-454X"]  journal           CO
# 775     2085-1189   ["2085-1189","2685-9971"]  journal           ID
# 864     2100-0719   ["2100-0719","2102-6246"]  journal           FR
# 1147    2618-897X   ["2618-8988","2618-897X"]  journal           RU
# ...           ...                         ...      ...          ...
# 143577  0096-2430   ["0096-2430","2379-8661"]  journal           US
# 144381  1816-9678   ["1816-9678","2059-9196"]  journal           GB
# 145906  2151-6200               ["2151-6200"]  journal           US
# 147179  2196-5420  ["2196-5420", "2196-5625"]  journal           DE
# 147516  0894-0819               ["0894-0819"]  journal         None
#
#                                          alternate_titles  publisher_id
# 432                                                    []  4.323253e+09  \
# 773                                                    []  4.310319e+09
# 775                [Kajian ilmu akuntansi dan terapannya]  4.310315e+09
# 864                                                    []  4.310320e+09
# 1147         [Polylinguality and transcultural practices]  4.310313e+09
# ...                                                   ...           ...
# 143577  [Electron devices, Transactions on electron de...  4.310320e+09
# 144381                                                 []  4.310312e+09
# 145906                                                 []  4.310320e+09
# 147179                                                 []  4.310320e+09
# 147516                                                 []  4.310320e+09
#
#         paper_count  citation_count
# 432          3872.0            35.0
# 773           126.0           116.0
# 775            61.0            25.0
# 864            44.0             3.0
# 1147          284.0            75.0
# ...             ...             ...
# 143577       1008.0          4373.0
# 144381       1255.0            81.0
# 145906        403.0           576.0
# 147179       1069.0         21442.0
# 147516        435.0          1840.0
#
# [8430 rows x 10 columns]

# %%
# %%time
# Source IDs that have already been through the updates should be protected
sq = """select source_id from issn_audit_20240321.update1 where reverted is false;"""
df1 = pd.read_sql_query(sq, db.engine)

sq = """select source_id from issn_audit_20240321.update2 where reverted is false;"""
df2 = pd.read_sql_query(sq, db.engine)

df_protected = pd.concat([df1, df2])
# Out:
# CPU times: user 77.9 ms, sys: 0 ns, total: 77.9 ms
# Wall time: 837 ms

# %%
df_protected
# Out:
#        source_id
# 0     4210234080
# 1     4387277910
# 2     4306499931
# 3     4210177666
# 4     4210223324
# ...          ...
# 8854  4393920245
# 8855  4393920246
# 8856  4393920247
# 8857  4393920248
# 8858  4393920249
#
# [134134 rows x 1 columns]

# %%
df_midjournal['is_protected'] = df_midjournal['journal_id'].isin(df_protected['source_id'].values)

# %%
df_midjournal['is_protected'].value_counts()
# Out:
# is_protected
# True     134124
# False     14291
# Name: count, dtype: int64

# %%
smap = {}
for source_id, issn_list in tqdm(df_midjournal.set_index('journal_id', verify_integrity=True)['issns_text_array'].items(), total=len(df_midjournal)):
    for issn in issn_list:
        if issn in smap:
            smap[issn].append(source_id)
        else:
            smap[issn] = [source_id]

# for issn in df_issnl_file['issns'].values:
#     s = df_midjournal['issns_text_array'].apply(lambda x: issn in x)
#     break
# Out:
# 100%|██████████| 148415/148415 [00:00<00:00, 362349.94it/s]

# %%
d = []
for issn, source_list in smap.items():
    d.append({
        'issn': issn,
        'num_sources': len(source_list),
    })
_df = pd.DataFrame(d)
_df['num_sources'].value_counts()
# Out:
# num_sources
# 1    209916
# 2      8272
# 3       196
# 4         8
# 5         2
# Name: count, dtype: int64

# %%
df_issnl_file['num_sources_resolve'] = df_issnl_file['issns'].map(_df.set_index('issn', verify_integrity=True)['num_sources'])

# %%
df_issnl_file['num_sources_resolve'].fillna(value=0, inplace=True)

# %%
df_issnl_file['num_sources_resolve'].value_counts()
# Out:
# num_sources_resolve
# 1.0    206164
# 2.0      8217
# 0.0       498
# 3.0       196
# 4.0         8
# 5.0         2
# Name: count, dtype: int64

# %%
df_issnl_file[df_issnl_file['num_sources_resolve']==2]
# Out:
#             issns  original_line_number valid_issns      issnl
# 65      1110-2098                    66   1110-2098  1110-2098  \
# 74      0966-1905                    75   0966-1905  0966-1905
# 132     2411-2933                   130   2411-2933  2411-3123
# 228     0889-325X                   222   0889-325X  0889-325X
# 229     1783-2446                   223   1783-2446  1783-2446
# ...           ...                   ...         ...        ...
# 214580  2734-0759                214579   2734-0759  1225-0759
# 214581  2734-0767                214580   2734-0767  1226-6787
# 214679  2764-1546                214679   2764-1546  2525-7374
# 215023  2815-5890                215024   2815-5890  2615-9783
# 215050  2957-4080                215051   2957-4080  2957-4080
#
#                                             diagnostics
# 65      1110-2098: Duplicates another ISSN in the file.  \
# 74                                                 None
# 132     2411-2933: Duplicates another ISSN in the file.
# 228     0889-325X: Duplicates another ISSN in the file.
# 229     1783-2446: Duplicates another ISSN in the file.
# ...                                                 ...
# 214580  2734-0759: Duplicates another ISSN in the file.
# 214581  2734-0767: Duplicates another ISSN in the file.
# 214679  2764-1546: Duplicates another ISSN in the file.
# 215023  2815-5890: Duplicates another ISSN in the file.
# 215050                                             None
#
#                                             cluster_title print_issn
# 65      Menoufia Medical Journal /Menoufia Medical Jou...  1110-2098  \
# 74                                          BMUS bulletin  0966-1905
# 132     International journal for innovation education...  2411-3123
# 228                                 ACI materials journal  0889-325X
# 229     Journal of the European Society of Women in Th...  1783-2454
# ...                                                   ...        ...
# 214580          Jaemu gwalli yeongu/Jae'mu gwanri yeon'gu  1225-0759
# 214581           Misul chiryo yeongu/Misul ci'ryo yeon'gu  1226-6787
# 214679                                    Braspen Journal  2525-7374
# 215023  Vietnam Journal of Earth sciences/Vietnam Jour...  2615-9783
# 215050           European journal of psychiatric trainees       None
#
#        print_category print_medium print_frequency  ... disk_medium
# 65           Register        Print      Semiannual  ...        None  \
# 74           Register        Print       Quarterly  ...        None
# 132          Register        Print         Monthly  ...        None
# 228          Register        Print       Bimonthly  ...        None
# 229          Register        Print          Annual  ...        None
# ...               ...          ...             ...  ...         ...
# 214580       Register        Print       Quarterly  ...        None
# 214581       Register        Print      Semiannual  ...        None
# 214679       Register        Print       Quarterly  ...        None
# 215023       Register        Print       Quarterly  ...        None
# 215050           None         None            None  ...        None
#
#        disk_frequency disk_country disk_center disk_language disk_start
# 65               None         None        None          None       None  \
# 74               None         None        None          None       None
# 132              None         None        None          None       None
# 228              None         None        None          None       None
# 229              None         None        None          None       None
# ...               ...          ...         ...           ...        ...
# 214580           None         None        None          None       None
# 214581           None         None        None          None       None
# 214679           None         None        None          None       None
# 215023           None         None        None          None       None
# 215050           None         None        None          None       None
#
#        disk_end disk_title disk_comment num_sources_resolve
# 65         None       None         None                 2.0
# 74         None       None         None                 2.0
# 132        None       None         None                 2.0
# 228        None       None         None                 2.0
# 229        None       None         None                 2.0
# ...         ...        ...          ...                 ...
# 214580     None       None         None                 2.0
# 214581     None       None         None                 2.0
# 214679     None       None         None                 2.0
# 215023     None       None         None                 2.0
# 215050     None       None         None                 2.0
#
# [8217 rows x 40 columns]

# %%
df_midjournal[df_midjournal['issns_text_array'].apply(lambda x: '0966-1905' in x)]
# Out:
#        journal_id   display_name       issn          issns issns_text_array
# 25890  2764892950  BMUS Bulletin  0966-1905  ["0966-1905"]      [0966-1905]  \
# 33326  4210217177  BMUS bulletin  0966-1905  ["0966-1905"]      [0966-1905]
#
#           type country_code                               alternate_titles
# 25890  journal         None                                             []  \
# 33326  journal           GB  [British Medical Ultrasound Society bulletin]
#
#        publisher_id  paper_count  citation_count
# 25890  4.310320e+09       1118.0           330.0
# 33326  4.310320e+09       1118.0           330.0

# %%
from cleanup.util import make_request

# %%
actual_works_count = {}
n = len([source_list for source_list in smap.values() if len(source_list) > 1])
for issn, source_list in tqdm(smap.items(), total=n):
    if len(source_list) > 1:
        actual_works_count[issn] = []
        for source_id in source_list:
            url = f'https://api.openalex.org/works?filter=locations.source.id:S{source_id}'
            params = {'mailto': 'jportenoy@ourresearch.org'}
            r = make_request(url, params=params)
            actual_works_count[issn].append((source_id, r.json()['meta']['count']))
# Out:
# 12984it [06:21, 34.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 9
#       7 url = f'https://api.openalex.org/works?filter=locations.source.id:S{source_id}'
#       8 params = {'mailto': 'jportenoy@ourresearch.org'}
# ----> 9 r = make_request(url, params=params)
#      10 actual_works_count[issn].append((source_id, r.json()['meta']['count']))
#
# File ~/code/ourresearch/openalex-guts/venv/lib/python3.9/site-packages/backoff/_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#      96 details = {
#      97     "target": target,
#      98     "args": args,
#    (...)
#     101     "elapsed": elapsed,
#     102 }
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#     107     max_tries_exceeded = (tries == max_tries_value)
#
# File ~/code/ourresearch/openalex-guts/venv/lib/python3.9/site-packages/backoff/_sync.py:48, in retry_predicate.<locals>.retry(*args, **kwargs)
#      39 elapsed = timedelta.total_seconds(datetime.datetime.now() - start)
#      40 details = {
#      41     "target": target,
#      42     "args": args,
#    (...)
#      45     "elapsed": elapsed,
#      46 }
# ---> 48 ret = target(*args, **kwargs)
#      49 if predicate(ret):
#      50     max_tries_exceeded = (tries == max_tries_value)
#
# File ~/code/ourresearch/openalex-guts/cleanup/notebooks/../../cleanup/util.py:143, in make_request(url, params)
#     141     return requests.get(url)
#     142 else:
# --> 143     return requests.get(url, params=params)
#
# File ~/code/ourresearch/openalex-guts/venv/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/code/ourresearch/openalex-guts/venv/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/code/ourresearch/openalex-guts/venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/code/ourresearch/openalex-guts/venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/code/ourresearch/openalex-guts/venv/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/code/ourresearch/openalex-guts/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#     713 response_conn = conn if not release_conn else None
#
# File ~/code/ourresearch/openalex-guts/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:445, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     440             httplib_response = conn.getresponse()
#     441         except BaseException as e:
#     442             # Remove the TypeError from the exception chain in
#     443             # Python 3 (including for exceptions like SystemExit).
#     444             # Otherwise it looks like a bug in the code.
# --> 445             six.raise_from(e, None)
#     446 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/code/ourresearch/openalex-guts/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:440, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     437 except TypeError:
#     438     # Python 3
#     439     try:
# --> 440         httplib_response = conn.getresponse()
#     441     except BaseException as e:
#     442         # Remove the TypeError from the exception chain in
#     443         # Python 3 (including for exceptions like SystemExit).
#     444         # Otherwise it looks like a bug in the code.
#     445         six.raise_from(e, None)
#
# File ~/miniconda3-py39/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/miniconda3-py39/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/miniconda3-py39/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/miniconda3-py39/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/miniconda3-py39/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3-py39/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:
